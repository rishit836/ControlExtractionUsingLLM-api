# %% [markdown]
# ### EXTRACTION CONTROLS FROM UNSTRUCTURED PDF USING LLM
# #### Using Qwen AI Model
# - for extraction of controls
# - validationof controls extracted using RAG

# %% [markdown]
# ##### Path of the File

# %%
# pdf_path = "uploads/NIST_CONTROL.pdf"
# pdf_path = "ISO_27001.pdf"
pdf_path  = "nist_file.pdf"

# %% [markdown]
# #### Reading Contents of the pdf and cleaning the pdf

# %%
import pypdf

# %%
reader = pypdf.PdfReader(pdf_path)

# %%
import re
def normalize_text(raw_text):

    # checking for empty string incase pdf has some
    if not raw_text:
        return ""

    # splitting lines
    lines = raw_text.split('\n')
    cleaned_lines = []

    # Generic noise patterns found the pdf[nist and iso]
    # defining the list because incase new patterns need to be added based on the pdf file.
    # These are safe to remove from ANY document.
    # We include a length check (len < 30) to ensure we don't accidentally
    # delete a real control that happens to contain the word "Page".
    noise_patterns = [
        r"^Page\s+\d+$",               # Matches "Page 1"
        r"^Page\s+\d+\s+of\s+\d+$",    # Matches "Page 1 of 10"
        r"^\d+\s+of\s+\d+$",           # Matches "1 of 10"
        r"^https?://",                 # URL artifacts often in footers
        r"^www\.",                     # Web links
        r"^\(c\)\s+\d{4}",             # Copyright markers like "(c) 2023"
        r"^Copyright",                 # Copyright word
        r'\bAppendix\s+[A-Z]+\s+Page\s+\d+\b'
    ]

    for line in lines:
        line = line.strip()

        # Skip empty lines
        if not line:
            continue

        # Check if line is noise
        is_noise = False
        # Only check short lines to be safe. If a line is 100 chars long,
        # it's likely content, even if it has "Page" in it.
    
        for pattern in noise_patterns:
            if re.search(pattern, line, re.IGNORECASE):
                is_noise = True
                break

        if not is_noise:
            cleaned_lines.append(line)

    # Merging all the lines into one text
    # We join with '\n' to preserve the structure.
    # The LLM needs to see the newlines to understand the layout.
    return '\n'.join(cleaned_lines)

# %%
text_page = []

for page in reader.pages[40:50]:
    page_cleaned = normalize_text(page.extract_text())
    text_page.append(page_cleaned)

# %% [markdown]
# #### Loading the Model in 4 bit because of vram limitations

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig,pipeline

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
# model_id = "meta-llama/Meta-Llama-3-8B-Instruct" # not using this as it requires login in hugging_face
model_id = "Qwen/Qwen2.5-7B-Instruct"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True
)
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [00:18<00:00,  4.64s/it]

# %%
def clean_and_validate_json(json):
    indices_to_remove = []
    seen_ids = set()
    for idx,control in enumerate(json):
        empty_string_type = ['','none',' ',None]
        if control['control_id'].lower() not in seen_ids:
            seen_ids.add(control['control_id'].lower())
        else:
            indices_to_remove.append(idx)
            continue
        if len(control['control_desc'])<3:
            indices_to_remove.append(idx)
            continue
        try:
            if control['control_id'].lower() in empty_string_type or control['control_title'].lower() in empty_string_type or control['control_desc'].lower() in empty_string_type:
                indices_to_remove.append(idx)
                continue
        except:
            # if it fails to find any one of the column in the json
            indices_to_remove.append(idx)
    json = [element for index, element in enumerate(json) if index not in indices_to_remove]
    return json

# %%
# Cell 5: Define the Extraction Logic

def extract_controls_from_page(page_text):
    # 1. The System Prompt (The Brains)
    system_prompt = """
    You are an expert Compliance Auditor specialized in ISO, NIST, and Regulatory frameworks.

    Task: Extract individual controls or regulatory requirements from the provided text. Ignore all boilerplate, headers, and irrelevant legal prose.

    Control ID Identification Logic:
    Identify control IDs using a pattern-matching approach for:
    1. Annex A style (e.g., A.5.1, A.12.1.1)
    2. NIST style (e.g., AC-1, PM-10)
    3. Legislative/Section style (e.g., Sec. 302, Sec. 404)

    Rules:
    - If controls are found, return ONLY a raw JSON list of objects.
    - Fields:
        - "control_id": The exact identifier (e.g., "Sec. 404", "A.5.1", or "AC-1").
        - "control_title": A concise title (5-10 words) as stated in the text.
        - "control_desc": The full description or specific requirement associated with that ID.
    - If NO controls are found, output strictly: []
    - Strict Formatting: No markdown, no "```json" blocks, no preamble. Just the raw JSON.
    """

    # 2. Structure the Chat
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"Analyze this text:\n\n{page_text}"}
    ]

    # 3. Prepare Inputs
    input_ids = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to(model.device)

    # 4. Generate
    outputs = model.generate(
        input_ids,
        max_new_tokens=4096,      # Limit output size to save time
        do_sample=False,         
        temperature=.1,          #so the model halluinates less
    )

    # 5. Decode
    response = tokenizer.decode(outputs[0][input_ids.shape[-1]:], skip_special_tokens=True)
    return response.strip()

# %% [markdown]
# #### Main Extraction Loop
# - the extraction loop gives the whole page chunk to the LLM, and LLM then returns the json output in a snippet

# %%
import json
import time

all_extracted_data = []
responses = []

total_start_time = time.time()  # Start global timer
print("Starting extraction...")

for i, page_text in enumerate(text_page):
    print(f"--- Processing Page {i+1} ---")


    page_start_time = time.time()


    raw_response = extract_controls_from_page(page_text)


    clean_json_string = raw_response.replace("```json", "").replace("```", "").strip()

    page_end_time = time.time()
    elapsed_time = page_end_time - page_start_time
    print(f"   > Time taken: {elapsed_time:.2f} seconds")
    responses.append(clean_json_string)

    try:

        if not clean_json_string or clean_json_string == "[]":
            print(f"   > No controls found.")
            continue

        data = json.loads(clean_json_string)

        # Verify it's a list
        if isinstance(data, list):
            count = len(data)
            print(f"   > Success! Found {count} controls.")
            for control in data:
                control['page']=i
            all_extracted_data.extend(data)
        else:
            print(f"   > Warning: Model returned valid JSON but not a list.")

    except json.JSONDecodeError:
        print(f"   > Error: Model output invalid JSON.\n   > Raw Output: {raw_response[:50]}...")

total_end_time = time.time()
total_duration = total_end_time - total_start_time
minutes = int(total_duration // 60)
seconds = int(total_duration % 60)
# Out:
# Starting extraction...
# --- Processing Page 1 ---
#    > Time taken: 0.29 seconds
#    > No controls found.
# --- Processing Page 2 ---
#    > Time taken: 0.21 seconds
#    > No controls found.
# --- Processing Page 3 ---
#    > Time taken: 0.27 seconds
#    > No controls found.
# --- Processing Page 4 ---
#    > Time taken: 0.21 seconds
#    > No controls found.
# --- Processing Page 5 ---
#    > Time taken: 1.75 seconds
#    > Success! Found 1 controls.
# --- Processing Page 6 ---
#    > Time taken: 1.77 seconds
#    > Success! Found 1 controls.
# --- Processing Page 7 ---
#    > Time taken: 33.19 seconds
#    > Success! Found 28 controls.
# --- Processing Page 8 ---
#    > Time taken: 4.63 seconds
#    > Success! Found 4 controls.
# --- Processing Page 9 ---
#    > Time taken: 1.19 seconds
#    > Success! Found 1 controls.
# --- Processing Page 10 ---
#    > Time taken: 41.68 seconds
#    > Success! Found 43 controls.

# %%
print("\nDONE!")
print(f"Total controls found: {len(all_extracted_data)}")
# Out:
# DONE!
# Total controls found: 78

# %%
with open("output_nist.json", "w") as f:
    json.dump(all_extracted_data, f, indent=2)

# %% [markdown]
# # To check for RAG Pipeline

# %%
import json
with open('output_nist.json',"r") as f:
    all_extracted_data = json.load(f)

# pdf_path = "ISO_27001.pdf"

# %%
import pypdf
reader = pypdf.PdfReader(pdf_path)

text_page = []

for page in reader.pages:
    text_page.append(page.extract_text())

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch
import json
import re
from huggingface_hub import login
from dotenv import load_dotenv
import os
load_dotenv()
login(os.environ['hf_api'])


def load_model(model_id="Qwen/Qwen2.5-7B-Instruct"):
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    )

    tokenizer = AutoTokenizer.from_pretrained(model_id)

    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
        
    # 2. Set padding side to 'left' for generation (Important for decoder-only models)
    tokenizer.padding_side = "left"

    # model
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=True
    )
    return tokenizer,model

def validate_controls(context,control_id,control_title,control_desc,tokenizer,model):
    validation_template = f"""
    You are a Quality Assurance Auditor. Verify if the following control exists in the source text.
    
    SOURCE TEXT (Reference):
    {context}
    
    CLAIMED CONTROL (To Verify):
    ID: {control_id}
    Title: {control_title}
    Description: {control_desc}
    
    TASK:
    Determine if the "Claimed Control" is explicitly supported by the "Source Text".
    Also make sure the control given isnt just a change made in any other control
    note: sometimes the "Claimed Control" might be just a table heading but not a valid control so make sure the claimed control is valid by 
    checking its description and reasoning it yourself.
    
    OUTPUT FORMAT:
    Return only a JSON object with this format:
    {{
        "is_valid": true/false,
        "reason": "Short explanation citing the text",
        "confidence_score": 1-10
    }}
    """
    messages = [
        {"role": "user", "content": validation_template}
    ]
    # message format
    input_ids = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to(model.device)

    # 4. Generate
    outputs = model.generate(
        input_ids,
        max_new_tokens=4096,      # Limit output size to save time
        do_sample=False,         # temperature=0 (Deterministic)
        temperature=None,        # Must be None if do_sample=False
        top_p=None               # Must be None if do_sample=False
    )

    # 5. Decode
    # Determine the length of input tokens so we only decode the new response tokens
    response_tokens = outputs[0][input_ids.shape[-1]:]
    response_text = tokenizer.decode(response_tokens, skip_special_tokens=True)
    # returning the response
    return clean_and_parse_json(response_text)


def clean_and_parse_json(text):
    """Helper to strip markdown code blocks and return a dict."""
    try:
        # 1. Try to find content inside ```json ... ```
        match = re.search(r"```json\s*(.*?)\s*```", text, re.DOTALL)
        if match:
            text_to_parse = match.group(1)
        else:
            # 2. If no code blocks, try to find the first '{' and last '}'
            # This handles cases where the model outputs text before/after the JSON without fences
            start = text.find('{')
            end = text.rfind('}')
            if start != -1 and end != -1:
                text_to_parse = text[start:end+1]
            else:
                # 3. Fallback to original cleanup
                text_to_parse = re.sub(r"```json\s*|\s*```", "", text.strip())
        
        return json.loads(text_to_parse)
    except json.JSONDecodeError:
        # Fallback if model fails to generate valid JSON
        return {"error": "Failed to parse JSON", "raw_output": text}


    
def validation_pipeline(control_list, text_pages,tokenizer,model):
    # tokenizer,model=load_model("DavidAU/Llama3.3-8B-Instruct-Thinking-Claude-4.5-Opus-High-Reasoning")
    
    for control in control_list:
        print("PROCCESSING CONTROL:",control['control_id'],end=" ")
        resp = validate_controls(text_pages[control['page']],control['control_id'],control['control_title'],control['control_desc'],tokenizer,model)
        try:
            print("PASS"if resp['is_valid'] else "FAIL")
        except:
            print("invalid json response.")
            print(resp)
        control['validation'] = resp
    return control_list

# %%
try:
    del tokenizer
    del model
except:
    print("tokenizer,model not defined")
import gc
import torch
torch.cuda.empty_cache()
gc.collect()

tokenizer,model=load_model()
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [00:10<00:00,  2.63s/it]

# %%
import warnings
import os
warnings.filterwarnings('ignore')
os.environ['TRANSFORMERS_VERBOSITY'] = 'error'
validated_list = validation_pipeline(all_extracted_data,text_page,tokenizer,model)
# Out:
# PROCCESSING CONTROL: AC-1 PASS
# PROCCESSING CONTROL: AC-2 PASS
# PROCCESSING CONTROL: AC-3 FAIL
# PROCCESSING CONTROL: AC-5 PASS
# PROCCESSING CONTROL: AC-6 PASS
# PROCCESSING CONTROL: AC-17 FAIL
# PROCCESSING CONTROL: AC-18 FAIL
# PROCCESSING CONTROL: AC-20 FAIL
# PROCCESSING CONTROL: AC-24 FAIL
# PROCCESSING CONTROL: AU-2 FAIL
# PROCCESSING CONTROL: AU-12 FAIL
# PROCCESSING CONTROL: CM-5 FAIL
# PROCCESSING CONTROL: IA-2 FAIL
# PROCCESSING CONTROL: IA-4 FAIL
# PROCCESSING CONTROL: IA-5 FAIL
# PROCCESSING CONTROL: IA-8 FAIL
# PROCCESSING CONTROL: MA-3 FAIL
# PROCCESSING CONTROL: MA-5 FAIL
# PROCCESSING CONTROL: PE-2 FAIL
# PROCCESSING CONTROL: PL-4 FAIL
# PROCCESSING CONTROL: PS-2 FAIL
# PROCCESSING CONTROL: PS-4 FAIL
# PROCCESSING CONTROL: PS-5 FAIL
# PROCCESSING CONTROL: PS-7 FAIL
# PROCCESSING CONTROL: PT-2 FAIL
# PROCCESSING CONTROL: PT-3 FAIL
# PROCCESSING CONTROL: SC-7 FAIL
# PROCCESSING CONTROL: SC-12 FAIL
# PROCCESSING CONTROL: SC-13 FAIL
# PROCCESSING CONTROL: SC-37 FAIL
# PROCCESSING CONTROL: AC-11 PASS
# PROCCESSING CONTROL: AU-2 PASS
# PROCCESSING CONTROL: AU-6 PASS
# PROCCESSING CONTROL: AC-16 PASS
# PROCCESSING CONTROL: AC-16 PASS
# PROCCESSING CONTROL: AC-3 PASS
# PROCCESSING CONTROL: AC-6 FAIL
# PROCCESSING CONTROL: AC-16 FAIL
# PROCCESSING CONTROL: AC-17 FAIL
# PROCCESSING CONTROL: AC-18 FAIL
# PROCCESSING CONTROL: AC-19 FAIL
# PROCCESSING CONTROL: AC-20 FAIL
# PROCCESSING CONTROL: AC-21 FAIL
# PROCCESSING CONTROL: AC-22 FAIL
# PROCCESSING CONTROL: AC-24 FAIL
# PROCCESSING CONTROL: AC-25 FAIL
# PROCCESSING CONTROL: AT-2 FAIL
# PROCCESSING CONTROL: AT-3 FAIL
# PROCCESSING CONTROL: AU-9 FAIL
# PROCCESSING CONTROL: CA-9 FAIL
# PROCCESSING CONTROL: CM-5 FAIL
# PROCCESSING CONTROL: CM-11 FAIL
# PROCCESSING CONTROL: IA-2 FAIL
# PROCCESSING CONTROL: IA-5 FAIL
# PROCCESSING CONTROL: IA-6 FAIL
# PROCCESSING CONTROL: IA-7 FAIL
# PROCCESSING CONTROL: IA-11 FAIL
# PROCCESSING CONTROL: MA-3 FAIL
# PROCCESSING CONTROL: MA-4 FAIL
# PROCCESSING CONTROL: MA-5 FAIL
# PROCCESSING CONTROL: MP-4 FAIL
# PROCCESSING CONTROL: PM-2 FAIL
# PROCCESSING CONTROL: PS-3 FAIL
# PROCCESSING CONTROL: PT-2 FAIL
# PROCCESSING CONTROL: PT-3 FAIL
# PROCCESSING CONTROL: SA-17 FAIL
# PROCCESSING CONTROL: SC-2 FAIL
# PROCCESSING CONTROL: SC-3 FAIL
# PROCCESSING CONTROL: SC-4 FAIL
# PROCCESSING CONTROL: SC-12 FAIL
# PROCCESSING CONTROL: SC-13 FAIL
# PROCCESSING CONTROL: SC-28 FAIL
# PROCCESSING CONTROL: SC-31 FAIL
# PROCCESSING CONTROL: SC-34 FAIL
# PROCCESSING CONTROL: SI-4 FAIL
# PROCCESSING CONTROL: SI-8 FAIL
# PROCCESSING CONTROL: CP-9 FAIL
# PROCCESSING CONTROL: MP-6 FAIL

# %%
validated_list_copy = validated_list.copy()
assert id(validated_list_copy )!= id(validated_list)

# %%
pass_count = 0
fail_count = 0
failed = []
for idx,control in enumerate(validated_list):
    if 'validation' in control:
        if not 'is_valid' in control['validation']:
            fail_count+=1
            failed.append([idx,control])
            print(control)
            continue

        if control['validation']['is_valid']:
            
            pass_count+=1
            
        else:
            print(control)
            fail_count+=1
            failed.append([idx,control])
    else:
        print(f"invalid control {control['control_id']}")
print(f"{pass_count} controls, passed out of {len(all_extracted_data)}. {fail_count} controls failed. \n log:{failed}")
# Out:
# {'control_id': 'AC-3', 'control_title': 'Account Management', 'control_desc': 'Establish and maintain accountability for system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The 'Account Management' control described in the 'Claimed Control' does not match the content provided in the 'Source Text'. The source text discusses the management of system accounts, including the creation, adjustment, and removal of accounts, as well as the establishment of temporary and emergency accounts. However, it does not explicitly mention establishing and maintaining accountability for system components, which is the core of the 'Account Management' control (AC-3) as described in the claimed control.", 'confidence_score': 8}}
# {'control_id': 'AC-17', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the principle of least privilege or periodic review of access as described in the claimed control AC-17. The text focuses on managing system accounts, including temporary and emergency accounts, and disabling them within defined time periods. While it discusses account management and disabling, it does not specifically address the principle of least privilege or periodic review of access.', 'confidence_score': 8}}
# {'control_id': 'AC-18', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the principle of least privilege or periodic review of access. The closest related content is found in the discussion of account management, which mentions account expiration and disabling, but does not specifically reference the principle of least privilege or periodic review.', 'confidence_score': 7}}
# {'control_id': 'AC-20', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The 'Claimed Control' (AC-20) does not explicitly support the description provided in the 'Claimed Control'. The source text discusses the management of system accounts, including the creation, modification, and disabling of accounts, as well as the management of temporary and emergency accounts. However, it does not specifically mention periodic review of access or the principle of least privilege as described in the 'Claimed Control'. The source text focuses more on the processes and policies related to account management rather than the periodic review and least privilege principles.", 'confidence_score': 8}}
# {'control_id': 'AC-24', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The 'Claimed Control' (AC-24) does not explicitly support the description provided in the 'Claimed Control'. The source text focuses on managing system accounts, including temporary and emergency accounts, and disabling them within an organization-defined time period. It does not specifically mention periodic review of access based on the principle of least privilege, which is a key aspect of the 'Claimed Control'. The source text discusses account management practices but does not cover the periodic review requirement mentioned in the 'Claimed Control'.", 'confidence_score': 8}}
# {'control_id': 'AU-2', 'control_title': 'Audit and Accountability', 'control_desc': 'Maintain audit records for system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The source text does not explicitly mention or support the 'Audit and Accountability' control (AU-2) which requires maintaining audit records for system components. The text focuses on account management and security program collaboration related to access controls and account lifecycles, but does not directly address the maintenance of audit records.", 'confidence_score': 8}}
# {'control_id': 'AU-12', 'control_title': 'Audit and Accountability', 'control_desc': 'Maintain audit records for system components and ensure that audit records are protected from unauthorized modification.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The source text does not explicitly mention or support the 'Audit and Accountability' control (AU-12) as described in the claimed control. The text focuses on account management and does not discuss maintaining audit records or protecting them from unauthorized modification.", 'confidence_score': 8}}
# {'control_id': 'CM-5', 'control_title': 'Configuration Management', 'control_desc': 'Ensure that system components are configured according to established security policies.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The source text does not explicitly mention or support the 'Configuration Management' control (CM-5) as described in the claimed control. The text focuses on account management and does not provide details on configuring system components according to established security policies.", 'confidence_score': 8}}
# {'control_id': 'IA-2', 'control_title': 'Identity and Access Management', 'control_desc': 'Ensure that user identities are unique and that user identities are managed according to established security policies.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is about managing system accounts and temporary/emergency accounts, but it does not cover the aspects of identity uniqueness and management as described in the claimed control.', 'confidence_score': 7}}
# {'control_id': 'IA-4', 'control_title': 'Identity and Access Management', 'control_desc': 'Ensure that user identities are unique and that user identities are managed according to established security policies and that user identities are managed according to established security policies.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is found in the discussion of account management and the disabling of accounts, but it does not directly address the uniqueness of user identities or the management of user identities according to established security policies as described in the claimed control.', 'confidence_score': 7}}
# {'control_id': 'IA-5', 'control_title': 'Identity and Access Management', 'control_desc': 'Ensure that user identities are unique and that user identities are managed according to established security policies and that user identities are managed according to established security policies.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is about managing system accounts and temporary/emergency accounts, but it does not directly address the uniqueness of user identities or the management of user identities according to established security policies as described in the claimed control.', 'confidence_score': 7}}
# {'control_id': 'IA-8', 'control_title': 'Identity and Access Management', 'control_desc': 'Ensure that user identities are unique and that user identities are managed according to established security policies and that user identities are managed according to established security policies.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is found in the discussion of account management and the disabling of accounts, but it does not directly address the uniqueness of user identities or the management of user identities according to established security policies as described in the claimed control.', 'confidence_score': 7}}
# {'control_id': 'MA-3', 'control_title': 'Media Protection', 'control_desc': 'Protect media containing sensitive information from unauthorized access and modification.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'MA-3' does not match any control mentioned in the source text. The source text discusses controls related to account management and does not mention any control titled 'Media Protection' or with the ID 'MA-3'.", 'confidence_score': 10}}
# {'control_id': 'MA-5', 'control_title': 'Media Protection', 'control_desc': 'Protect media containing sensitive information from unauthorized access and modification and ensure that media containing sensitive information are protected from unauthorized access and modification.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control ID MA-5, titled 'Media Protection', does not appear to be directly supported by the provided source text. The source text focuses on account management and access controls, specifically related to system accounts, temporary accounts, and emergency accounts. There is no mention of media protection or safeguarding media containing sensitive information from unauthorized access and modification.", 'confidence_score': 9}}
# {'control_id': 'PE-2', 'control_title': 'Physical and Environmental Protection', 'control_desc': 'Ensure that physical and environmental controls are implemented to protect system components from unauthorized access and modification.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The claimed control (PE-2) does not appear to be directly related to the content of the source text. The source text discusses account management and security policies for access to systems, particularly focusing on temporary and emergency accounts, account expiration, and account management processes. There is no mention of physical and environmental protection measures, which would be more aligned with the Physical and Environmental Protection control (PE-2).', 'confidence_score': 9}}
# {'control_id': 'PL-4', 'control_title': 'Planning and Assessment', 'control_desc': 'Ensure that plans and assessments are developed and maintained to support the security of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control ID PL-4, titled 'Planning and Assessment', does not appear to be directly supported by the provided source text. The source text focuses on account management, specifically on the creation, modification, and disabling of system accounts, as well as the management of temporary and emergency accounts. There is no mention of planning and assessment activities related to the security of system components in the given text.", 'confidence_score': 9}}
# {'control_id': 'PS-2', 'control_title': 'Personnel Security', 'control_desc': 'Ensure that personnel security policies and procedures are developed and maintained to support the security of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The source text does not explicitly mention or support the 'Personnel Security' control (PS-2). The text focuses on account management and access controls, particularly related to system accounts, temporary accounts, and emergency accounts. There is no direct reference to personnel security policies and procedures in the provided text.", 'confidence_score': 8}}
# {'control_id': 'PS-4', 'control_title': 'Personnel Security', 'control_desc': 'Ensure that personnel security policies and procedures are developed and maintained to support the security of system components and that personnel security policies and procedures are developed and maintained to support the security of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The source text does not explicitly mention 'Personnel Security' policies or procedures. The text focuses on account management and access controls related to system accounts, which are more aligned with Access Control (AC) and Audit and Accountability (AU) controls rather than Personnel Security (PS) controls. The claimed control (PS-4) is about personnel security policies and procedures, which is not directly addressed in the provided source text.", 'confidence_score': 8}}
# {'control_id': 'PS-5', 'control_title': 'Personnel Security', 'control_desc': 'Ensure that personnel security policies and procedures are developed and maintained to support the security of system components and that personnel security policies and procedures are developed and maintained to support the security of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The source text does not explicitly mention 'Personnel Security' policies or procedures. The text focuses on account management and access controls related to system accounts, which are more aligned with Access Control (AC) and Audit and Accountability (AU) controls rather than Personnel Security (PS) controls. The claimed control PS-5 is not directly supported by the provided source text.", 'confidence_score': 8}}
# {'control_id': 'PS-7', 'control_title': 'Personnel Security', 'control_desc': 'Ensure that personnel security policies and procedures are developed and maintained to support the security of system components and that personnel security policies and procedures are developed and maintained to support the security of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The claimed control (PS-7: Personnel Security) does not appear to be directly supported by the provided source text. The source text discusses account management and security program collaboration related to access controls, but it does not explicitly mention personnel security policies and procedures as described in the claimed control.', 'confidence_score': 8}}
# {'control_id': 'PT-2', 'control_title': 'Protection from Unauthorized Modification or Disclosure', 'control_desc': 'Ensure that protection measures are implemented to prevent unauthorized modification or disclosure of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control PT-2, titled 'Protection from Unauthorized Modification or Disclosure', does not appear to be directly supported by the provided source text. The source text focuses on account management, particularly the creation, adjustment, and removal of system accounts, and the management of temporary and emergency accounts. It does not explicitly address measures to prevent unauthorized modification or disclosure of system components.", 'confidence_score': 8}}
# {'control_id': 'PT-3', 'control_title': 'Protection from Unauthorized Modification or Disclosure', 'control_desc': 'Ensure that protection measures are implemented to prevent unauthorized modification or disclosure of system components and that protection measures are implemented to prevent unauthorized modification or disclosure of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control PT-3 titled 'Protection from Unauthorized Modification or Disclosure' does not appear to be directly supported by the provided source text. The source text discusses account management, including the creation, modification, and disabling of system accounts, but does not specifically address measures to prevent unauthorized modification or disclosure of system components. The focus of the source text is on account management practices rather than protection against unauthorized modifications or disclosures.", 'confidence_score': 8}}
# {'control_id': 'SC-7', 'control_title': 'System and Communications Protection', 'control_desc': 'Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control (SC-7) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, which are related to access controls and account lifecycle management, but it does not explicitly address 'System and Communications Protection' measures to prevent unauthorized access and modification of system components. The focus of the text is on managing system accounts and their lifecycles, rather than on protecting system and communication components from unauthorized access and modification.", 'confidence_score': 8}}
# {'control_id': 'SC-12', 'control_title': 'System and Communications Protection', 'control_desc': 'Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components and that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control (SC-12) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, which are related to access controls and account lifecycle management, but it does not explicitly address 'System and Communications Protection' as described in the claimed control. The focus of the source text is on managing system accounts and ensuring appropriate access controls, rather than on protecting system and communication components from unauthorized access and modification.", 'confidence_score': 8}}
# {'control_id': 'SC-13', 'control_title': 'System and Communications Protection', 'control_desc': 'Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components and that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The claimed control (SC-13) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, which are related to access controls and account lifecycle management, but it does not explicitly address 'System and Communications Protection' as described in the claimed control. The focus of the text is on managing system accounts and ensuring appropriate access controls, rather than on protecting system and communication components from unauthorized access and modification.", 'confidence_score': 8}}
# {'control_id': 'SC-37', 'control_title': 'System and Communications Protection', 'control_desc': 'Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components and that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The claimed control (SC-37) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, but does not explicitly address system and communications protection measures to prevent unauthorized access and modification of system components, which is the focus of the claimed control.', 'confidence_score': 8}}
# {'control_id': 'AC-6', 'control_title': 'ACCESS ENFORCEMENT | RESTRICTED ACCESS TO PRIVILEGED FUNCTIONS', 'control_desc': '[Withdrawn: Incorporated into AC-6.]', 'page': 9, 'validation': {'is_valid': False, 'reason': "The 'Claimed Control' titled 'ACCESS ENFORCEMENT | RESTRICTED ACCESS TO PRIVILEGED FUNCTIONS' is described as [Withdrawn: Incorporated into AC-6]. This indicates that it has been withdrawn and its content is now part of AC-6, rather than being a separate control. The source text does not explicitly mention this specific control as a standalone entity.", 'confidence_score': 8}}
# {'control_id': 'AC-16', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': 'The claimed control ID AC-16 is not explicitly mentioned or supported in the provided source text. The text discusses AC-3, which is about enforcing approved authorizations for logical access, but does not mention AC-16 specifically. Additionally, the description provided for the claimed control is not found in the source text.', 'confidence_score': 8}}
# {'control_id': 'AC-17', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID AC-17 is not explicitly mentioned in the source text. The text discusses AC-3, which is about 'ACCESS ENFORCEMENT', but does not provide a detailed description for AC-17. Additionally, the description provided for the claimed control is not found in the source text.", 'confidence_score': 8}}
# {'control_id': 'AC-18', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'ACCESS ENFORCEMENT' (ID: AC-18) is not explicitly stated in the source text. The source text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not mention AC-18 specifically. Additionally, the description provided for the claimed control is not found in the source text.", 'confidence_score': 8}}
# {'control_id': 'AC-19', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'ACCESS ENFORCEMENT' (ID: AC-19) is not explicitly stated in the source text. The source text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not mention AC-19 specifically. Additionally, the description provided for the claimed control is not found in the source text.", 'confidence_score': 8}}
# {'control_id': 'AC-20', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID AC-20 is not explicitly mentioned or referenced in the provided source text. The text discusses AC-3, which is about 'ACCESS ENFORCEMENT', but does not provide a detailed description of AC-20 as claimed. Additionally, there is no mention of any control enhancements or specific details that would align with AC-20.", 'confidence_score': 8}}
# {'control_id': 'AC-21', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID AC-21 is not explicitly mentioned or referenced in the provided source text. The text discusses AC-3, which is about 'ACCESS ENFORCEMENT', but does not provide a detailed description for AC-21. Additionally, there is no mention of any control enhancements or specific details that would align with AC-21.", 'confidence_score': 8}}
# {'control_id': 'AC-22', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID AC-22 is not explicitly mentioned or referenced in the provided source text. The text discusses AC-3, which is about 'ACCESS ENFORCEMENT', but does not provide a detailed description for AC-22. Additionally, there is no mention of any control enhancements or specific details that would align with AC-22.", 'confidence_score': 8}}
# {'control_id': 'AC-24', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID AC-24 is not explicitly mentioned in the source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a detailed description for AC-24. Additionally, there is no mention of a specific control enhancement or additional discussion related to AC-24 in the provided text.", 'confidence_score': 8}}
# {'control_id': 'AC-25', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID AC-25 is not explicitly mentioned in the source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a detailed description for AC-25. Additionally, there is no mention of a control titled 'ACCESS ENFORCEMENT' being divided into multiple sub-controls like AC-25 in the provided text.", 'confidence_score': 8}}
# {'control_id': 'AT-2', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'AT-2' does not appear in the provided source text. The source text discusses 'ACCESS ENFORCEMENT' under control AC-3, but there is no mention of a control with ID 'AT-2'. Additionally, the description provided for 'AT-2' is not found in the text and seems to be a generic description of access enforcement rather than a specific control.", 'confidence_score': 9}}
# {'control_id': 'AT-3', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'AT-3' does not appear in the provided source text. The closest relevant control discussed is 'AC-3 ACCESS ENFORCEMENT', which is described in detail. The term 'AT-3' is not mentioned or referenced in the text.", 'confidence_score': 10}}
# {'control_id': 'AU-9', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': 'The claimed control AU-9 is not explicitly mentioned or supported in the provided source text. The closest related control is AC-3, which discusses enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of AU-9 in the text.', 'confidence_score': 8}}
# {'control_id': 'CA-9', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'CA-9' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not mention 'CA-9' specifically. The description of 'CA-9' is implied rather than stated directly.", 'confidence_score': 8}}
# {'control_id': 'CM-5', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control CM-5 is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a specific control titled CM-5. The description of CM-5 is implied as part of the AC-3 discussion, which is not sufficient to validate it as a separate control.", 'confidence_score': 8}}
# {'control_id': 'CM-11', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'CM-11' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'CM-11'. Additionally, there is no explicit description of 'CM-11' in the given text.", 'confidence_score': 8}}
# {'control_id': 'IA-2', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'IA-2' is not explicitly mentioned in the source text. The closest related control is 'AC-3', which discusses access enforcement but does not specifically reference 'IA-2'. The description provided for 'IA-2' is implied rather than explicitly stated in the text.", 'confidence_score': 7}}
# {'control_id': 'IA-5', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'IA-5' is not explicitly mentioned or referenced in the provided source text. The closest related control is 'AC-3', which discusses access enforcement but does not specifically mention 'IA-5'. The description of 'IA-5' is implied rather than explicitly stated in the text.", 'confidence_score': 8}}
# {'control_id': 'IA-6', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'IA-6' is not explicitly mentioned or referenced in the provided source text. The closest related control is 'AC-3', which discusses access enforcement but does not specifically mention 'IA-6'. The description of 'IA-6' is implied rather than explicitly stated in the text.", 'confidence_score': 8}}
# {'control_id': 'IA-7', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'IA-7' is not explicitly mentioned or referenced in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a specific description for 'IA-7'. The description of 'IA-7' is implied rather than explicitly stated in the text.", 'confidence_score': 8}}
# {'control_id': 'IA-11', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID 'IA-11' is not explicitly mentioned or referenced in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a specific control titled 'IA-11'. The description of 'IA-11' is not found in the given text, and the text does not imply the existence of such a control.", 'confidence_score': 8}}
# {'control_id': 'MA-3', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'MA-3' is not explicitly mentioned in the source text. The closest related control is 'AC-3', which discusses access enforcement but does not reference 'MA-3'. Additionally, 'MA-3' is not a valid control in NIST SP 800-53 R5.", 'confidence_score': 8}}
# {'control_id': 'MA-4', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'MA-4 ACCESS ENFORCEMENT' is not explicitly mentioned or supported in the provided source text. The closest related control discussed is 'AC-3 ACCESS ENFORCEMENT', which focuses on enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of 'MA-4' or any control with a similar title or description in the given text.", 'confidence_score': 8}}
# {'control_id': 'MA-5', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'MA-5' is not explicitly mentioned or supported in the provided source text. The text discusses 'AC-3 ACCESS ENFORCEMENT' and related controls, but does not mention 'MA-5'. The description of 'ACCESS ENFORCEMENT' is implied in the context of 'AC-3', but 'MA-5' is not referenced or defined.", 'confidence_score': 8}}
# {'control_id': 'MP-4', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID MP-4 is not explicitly mentioned or referenced in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a specific description for a control with ID MP-4. Additionally, the description provided for the claimed control is not found in the text and seems to be inferred rather than explicitly stated.", 'confidence_score': 8}}
# {'control_id': 'PM-2', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'PM-2' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'PM-2'. Additionally, the description of the claimed control is not found in the text and appears to be a generic title rather than a specific control.", 'confidence_score': 8}}
# {'control_id': 'PS-3', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'PS-3' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference a specific control 'PS-3'. The description of 'ACCESS ENFORCEMENT' is implied rather than explicitly stated as a separate control.", 'confidence_score': 8}}
# {'control_id': 'PT-2', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control PT-2 is not explicitly mentioned in the source text. The source text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not provide a specific control titled PT-2. The description provided for PT-2 is implied and not directly supported by the text.", 'confidence_score': 8}}
# {'control_id': 'PT-3', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control PT-3 is not explicitly mentioned in the source text. The source text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not provide a specific control titled PT-3. The description provided for PT-3 is implied and not directly supported by the text.", 'confidence_score': 8}}
# {'control_id': 'SA-17', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SA-17' is not explicitly mentioned or referenced in the provided source text. The closest related control discussed is 'AC-3', which focuses on enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of 'SA-17' or any control with a similar title or description in the given text.", 'confidence_score': 8}}
# {'control_id': 'SC-2', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-2' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not reference 'SC-2'. Additionally, there is no explicit description of 'SC-2' in the given text.", 'confidence_score': 8}}
# {'control_id': 'SC-3', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-3 ACCESS ENFORCEMENT' is not explicitly mentioned or supported in the provided source text. The closest related content is found in the 'AC-3 ACCESS ENFORCEMENT' section, which discusses enforcing approved authorizations for logical access to information and system resources. The term 'SC-3' does not appear in the source text and there is no explicit reference to 'ACCESS ENFORCEMENT' under the 'SC' category.", 'confidence_score': 8}}
# {'control_id': 'SC-4', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-4 ACCESS ENFORCEMENT' is not explicitly mentioned or supported in the provided source text. The closest related control discussed is 'AC-3 ACCESS ENFORCEMENT', which focuses on enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of 'SC-4' or any control with a similar title or description in the given text.", 'confidence_score': 8}}
# {'control_id': 'SC-12', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-12' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'SC-12'. Additionally, the description of 'ACCESS ENFORCEMENT' is implied rather than explicitly stated as a separate control.", 'confidence_score': 8}}
# {'control_id': 'SC-13', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-13' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'SC-13'. Additionally, the description of 'ACCESS ENFORCEMENT' provided in the text does not match the title of 'SC-13', which would typically refer to mandatory access control.", 'confidence_score': 8}}
# {'control_id': 'SC-28', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-28' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'SC-28'. Additionally, the description of 'ACCESS ENFORCEMENT' is implied rather than explicitly stated as a separate control.", 'confidence_score': 8}}
# {'control_id': 'SC-31', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-31' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'SC-31'. Additionally, the description of 'ACCESS ENFORCEMENT' is broad and does not specifically align with the detailed requirements of 'SC-31'.", 'confidence_score': 8}}
# {'control_id': 'SC-34', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SC-34' titled 'ACCESS ENFORCEMENT' is not explicitly stated or supported in the provided source text. The source text discusses 'AC-3 ACCESS ENFORCEMENT' and related controls, but does not mention 'SC-34'. The description of 'ACCESS ENFORCEMENT' in the source text is more aligned with 'AC-3' rather than 'SC-34'.", 'confidence_score': 8}}
# {'control_id': 'SI-4', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SI-4' is not explicitly mentioned or supported in the provided source text. The text discusses 'AC-3 ACCESS ENFORCEMENT' and mentions 'SI-4' in the context of related controls, but does not describe 'SI-4' as an independent control. Therefore, the claimed control cannot be validated based on the given text.", 'confidence_score': 8}}
# {'control_id': 'SI-8', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Not explicitly stated but implied as part of the AC-3 discussion.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control 'SI-8' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not mention 'SI-8'. The description of the claimed control is implied rather than explicitly stated in the text.", 'confidence_score': 8}}
# {'control_id': 'CP-9', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Enforce dual authorization for [Assignment: organization-defined privileged commands and/or other organization-defined actions].', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID CP-9 and title 'ACCESS ENFORCEMENT' do not match the content in the source text. The source text discusses 'ACCESS ENFORCEMENT' under a different control ID (AC-3) and does not mention CP-9 or dual authorization for privileged commands under that section.", 'confidence_score': 8}}
# {'control_id': 'MP-6', 'control_title': 'ACCESS ENFORCEMENT', 'control_desc': 'Dual authorization mechanisms reduce risk related to insider threats.', 'page': 9, 'validation': {'is_valid': False, 'reason': "The claimed control ID MP-6 and title 'ACCESS ENFORCEMENT' does not match any control in the provided source text. The closest related control is AC-6, which discusses dual authorization, but it is noted that this has been incorporated into AC-6. The claimed control description is also not found in the source text.", 'confidence_score': 8}}
# 10 controls, passed out of 78. 68 controls failed.
#  log:[[2, {'control_id': 'AC-3', 'control_title': 'Account Management', 'control_desc': 'Establish and maintain accountability for system components.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The 'Account Management' control described in the 'Claimed Control' does not match the content provided in the 'Source Text'. The source text discusses the management of system accounts, including the creation, adjustment, and removal of accounts, as well as the establishment of temporary and emergency accounts. However, it does not explicitly mention establishing and maintaining accountability for system components, which is the core of the 'Account Management' control (AC-3) as described in the claimed control.", 'confidence_score': 8}}], [5, {'control_id': 'AC-17', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the principle of least privilege or periodic review of access as described in the claimed control AC-17. The text focuses on managing system accounts, including temporary and emergency accounts, and disabling them within defined time periods. While it discusses account management and disabling, it does not specifically address the principle of least privilege or periodic review of access.', 'confidence_score': 8}}], [6, {'control_id': 'AC-18', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': 'The source text does not explicitly mention the principle of least privilege or periodic review of access. The closest related content is found in the discussion of account management, which mentions account expiration and disabling, but does not specifically reference the principle of least privilege or periodic review.', 'confidence_score': 7}}], [7, {'control_id': 'AC-20', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The 'Claimed Control' (AC-20) does not explicitly support the description provided in the 'Claimed Control'. The source text discusses the management of system accounts, including the creation, modification, and disabling of accounts, as well as the management of temporary and emergency accounts. However, it does not specifically mention periodic review of access or the principle of least privilege as described in the 'Claimed Control'. The source text focuses more on the processes and policies related to account management rather than the periodic review and least privilege principles.", 'confidence_score': 8}}], [8, {'control_id': 'AC-24', 'control_title': 'Account Management', 'control_desc': 'Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.', 'page': 6, 'validation': {'is_valid': False, 'reason': "The 'Claimed Control' (AC-24) does not explicitly support the description provided in the 'Claimed Control'. The source text focuses on managing system accounts, including temporary and emergency accounts, and disabling them within an organization-defined time period. It does not specifically mention periodic review of access based on the principle of leas ...

# %%
cleaned_controls = []
seen_ids = set()
for control in validated_list_copy:
    if 'validation' in control:
        if not 'is_valid' in control['validation']:
            continue
        if control['control_id'] in seen_ids:
            continue
        else:
            seen_ids.add(control['control_id'])
        if not control['validation']['is_valid']:
            cleaned_controls.append(control)
        else:
            fail_count+=1
    else:
        print(f"invalid control {control['control_id']}")

print(json.dumps(cleaned_controls,indent=2))
# print(len(cleaned_controls))
# Out:
# [
#   {
#     "control_id": "AC-3",
#     "control_title": "Account Management",
#     "control_desc": "Establish and maintain accountability for system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The 'Account Management' control described in the 'Claimed Control' does not match the content provided in the 'Source Text'. The source text discusses the management of system accounts, including the creation, adjustment, and removal of accounts, as well as the establishment of temporary and emergency accounts. However, it does not explicitly mention establishing and maintaining accountability for system components, which is the core of the 'Account Management' control (AC-3) as described in the claimed control.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AC-17",
#     "control_title": "Account Management",
#     "control_desc": "Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention the principle of least privilege or periodic review of access as described in the claimed control AC-17. The text focuses on managing system accounts, including temporary and emergency accounts, and disabling them within defined time periods. While it discusses account management and disabling, it does not specifically address the principle of least privilege or periodic review of access.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AC-18",
#     "control_title": "Account Management",
#     "control_desc": "Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention the principle of least privilege or periodic review of access. The closest related content is found in the discussion of account management, which mentions account expiration and disabling, but does not specifically reference the principle of least privilege or periodic review.",
#       "confidence_score": 7
#     }
#   },
#   {
#     "control_id": "AC-20",
#     "control_title": "Account Management",
#     "control_desc": "Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The 'Claimed Control' (AC-20) does not explicitly support the description provided in the 'Claimed Control'. The source text discusses the management of system accounts, including the creation, modification, and disabling of accounts, as well as the management of temporary and emergency accounts. However, it does not specifically mention periodic review of access or the principle of least privilege as described in the 'Claimed Control'. The source text focuses more on the processes and policies related to account management rather than the periodic review and least privilege principles.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AC-24",
#     "control_title": "Account Management",
#     "control_desc": "Manage user accounts to ensure that access is granted based on the principle of least privilege and that access is reviewed periodically and that access is granted based on the principle of least privilege and that access is reviewed periodically.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The 'Claimed Control' (AC-24) does not explicitly support the description provided in the 'Claimed Control'. The source text focuses on managing system accounts, including temporary and emergency accounts, and disabling them within an organization-defined time period. It does not specifically mention periodic review of access based on the principle of least privilege, which is a key aspect of the 'Claimed Control'. The source text discusses account management practices but does not cover the periodic review requirement mentioned in the 'Claimed Control'.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AU-2",
#     "control_title": "Audit and Accountability",
#     "control_desc": "Maintain audit records for system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention or support the 'Audit and Accountability' control (AU-2) which requires maintaining audit records for system components. The text focuses on account management and security program collaboration related to access controls and account lifecycles, but does not directly address the maintenance of audit records.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AU-12",
#     "control_title": "Audit and Accountability",
#     "control_desc": "Maintain audit records for system components and ensure that audit records are protected from unauthorized modification.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention or support the 'Audit and Accountability' control (AU-12) as described in the claimed control. The text focuses on account management and does not discuss maintaining audit records or protecting them from unauthorized modification.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "CM-5",
#     "control_title": "Configuration Management",
#     "control_desc": "Ensure that system components are configured according to established security policies.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention or support the 'Configuration Management' control (CM-5) as described in the claimed control. The text focuses on account management and does not provide details on configuring system components according to established security policies.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "IA-2",
#     "control_title": "Identity and Access Management",
#     "control_desc": "Ensure that user identities are unique and that user identities are managed according to established security policies.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is about managing system accounts and temporary/emergency accounts, but it does not cover the aspects of identity uniqueness and management as described in the claimed control.",
#       "confidence_score": 7
#     }
#   },
#   {
#     "control_id": "IA-4",
#     "control_title": "Identity and Access Management",
#     "control_desc": "Ensure that user identities are unique and that user identities are managed according to established security policies and that user identities are managed according to established security policies.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is found in the discussion of account management and the disabling of accounts, but it does not directly address the uniqueness of user identities or the management of user identities according to established security policies as described in the claimed control.",
#       "confidence_score": 7
#     }
#   },
#   {
#     "control_id": "IA-5",
#     "control_title": "Identity and Access Management",
#     "control_desc": "Ensure that user identities are unique and that user identities are managed according to established security policies and that user identities are managed according to established security policies.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is about managing system accounts and temporary/emergency accounts, but it does not directly address the uniqueness of user identities or the management of user identities according to established security policies as described in the claimed control.",
#       "confidence_score": 7
#     }
#   },
#   {
#     "control_id": "IA-8",
#     "control_title": "Identity and Access Management",
#     "control_desc": "Ensure that user identities are unique and that user identities are managed according to established security policies and that user identities are managed according to established security policies.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention the uniqueness of user identities or the management of user identities according to established security policies. The closest related content is found in the discussion of account management and the disabling of accounts, but it does not directly address the uniqueness of user identities or the management of user identities according to established security policies as described in the claimed control.",
#       "confidence_score": 7
#     }
#   },
#   {
#     "control_id": "MA-3",
#     "control_title": "Media Protection",
#     "control_desc": "Protect media containing sensitive information from unauthorized access and modification.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID 'MA-3' does not match any control mentioned in the source text. The source text discusses controls related to account management and does not mention any control titled 'Media Protection' or with the ID 'MA-3'.",
#       "confidence_score": 10
#     }
#   },
#   {
#     "control_id": "MA-5",
#     "control_title": "Media Protection",
#     "control_desc": "Protect media containing sensitive information from unauthorized access and modification and ensure that media containing sensitive information are protected from unauthorized access and modification.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID MA-5, titled 'Media Protection', does not appear to be directly supported by the provided source text. The source text focuses on account management and access controls, specifically related to system accounts, temporary accounts, and emergency accounts. There is no mention of media protection or safeguarding media containing sensitive information from unauthorized access and modification.",
#       "confidence_score": 9
#     }
#   },
#   {
#     "control_id": "PE-2",
#     "control_title": "Physical and Environmental Protection",
#     "control_desc": "Ensure that physical and environmental controls are implemented to protect system components from unauthorized access and modification.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control (PE-2) does not appear to be directly related to the content of the source text. The source text discusses account management and security policies for access to systems, particularly focusing on temporary and emergency accounts, account expiration, and account management processes. There is no mention of physical and environmental protection measures, which would be more aligned with the Physical and Environmental Protection control (PE-2).",
#       "confidence_score": 9
#     }
#   },
#   {
#     "control_id": "PL-4",
#     "control_title": "Planning and Assessment",
#     "control_desc": "Ensure that plans and assessments are developed and maintained to support the security of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID PL-4, titled 'Planning and Assessment', does not appear to be directly supported by the provided source text. The source text focuses on account management, specifically on the creation, modification, and disabling of system accounts, as well as the management of temporary and emergency accounts. There is no mention of planning and assessment activities related to the security of system components in the given text.",
#       "confidence_score": 9
#     }
#   },
#   {
#     "control_id": "PS-2",
#     "control_title": "Personnel Security",
#     "control_desc": "Ensure that personnel security policies and procedures are developed and maintained to support the security of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention or support the 'Personnel Security' control (PS-2). The text focuses on account management and access controls, particularly related to system accounts, temporary accounts, and emergency accounts. There is no direct reference to personnel security policies and procedures in the provided text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "PS-4",
#     "control_title": "Personnel Security",
#     "control_desc": "Ensure that personnel security policies and procedures are developed and maintained to support the security of system components and that personnel security policies and procedures are developed and maintained to support the security of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention 'Personnel Security' policies or procedures. The text focuses on account management and access controls related to system accounts, which are more aligned with Access Control (AC) and Audit and Accountability (AU) controls rather than Personnel Security (PS) controls. The claimed control (PS-4) is about personnel security policies and procedures, which is not directly addressed in the provided source text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "PS-5",
#     "control_title": "Personnel Security",
#     "control_desc": "Ensure that personnel security policies and procedures are developed and maintained to support the security of system components and that personnel security policies and procedures are developed and maintained to support the security of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The source text does not explicitly mention 'Personnel Security' policies or procedures. The text focuses on account management and access controls related to system accounts, which are more aligned with Access Control (AC) and Audit and Accountability (AU) controls rather than Personnel Security (PS) controls. The claimed control PS-5 is not directly supported by the provided source text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "PS-7",
#     "control_title": "Personnel Security",
#     "control_desc": "Ensure that personnel security policies and procedures are developed and maintained to support the security of system components and that personnel security policies and procedures are developed and maintained to support the security of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control (PS-7: Personnel Security) does not appear to be directly supported by the provided source text. The source text discusses account management and security program collaboration related to access controls, but it does not explicitly mention personnel security policies and procedures as described in the claimed control.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "PT-2",
#     "control_title": "Protection from Unauthorized Modification or Disclosure",
#     "control_desc": "Ensure that protection measures are implemented to prevent unauthorized modification or disclosure of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control PT-2, titled 'Protection from Unauthorized Modification or Disclosure', does not appear to be directly supported by the provided source text. The source text focuses on account management, particularly the creation, adjustment, and removal of system accounts, and the management of temporary and emergency accounts. It does not explicitly address measures to prevent unauthorized modification or disclosure of system components.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "PT-3",
#     "control_title": "Protection from Unauthorized Modification or Disclosure",
#     "control_desc": "Ensure that protection measures are implemented to prevent unauthorized modification or disclosure of system components and that protection measures are implemented to prevent unauthorized modification or disclosure of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control PT-3 titled 'Protection from Unauthorized Modification or Disclosure' does not appear to be directly supported by the provided source text. The source text discusses account management, including the creation, modification, and disabling of system accounts, but does not specifically address measures to prevent unauthorized modification or disclosure of system components. The focus of the source text is on account management practices rather than protection against unauthorized modifications or disclosures.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-7",
#     "control_title": "System and Communications Protection",
#     "control_desc": "Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control (SC-7) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, which are related to access controls and account lifecycle management, but it does not explicitly address 'System and Communications Protection' measures to prevent unauthorized access and modification of system components. The focus of the text is on managing system accounts and their lifecycles, rather than on protecting system and communication components from unauthorized access and modification.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-12",
#     "control_title": "System and Communications Protection",
#     "control_desc": "Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components and that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control (SC-12) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, which are related to access controls and account lifecycle management, but it does not explicitly address 'System and Communications Protection' as described in the claimed control. The focus of the source text is on managing system accounts and ensuring appropriate access controls, rather than on protecting system and communication components from unauthorized access and modification.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-13",
#     "control_title": "System and Communications Protection",
#     "control_desc": "Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components and that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control (SC-13) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, which are related to access controls and account lifecycle management, but it does not explicitly address 'System and Communications Protection' as described in the claimed control. The focus of the text is on managing system accounts and ensuring appropriate access controls, rather than on protecting system and communication components from unauthorized access and modification.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-37",
#     "control_title": "System and Communications Protection",
#     "control_desc": "Ensure that system and communications protection measures are implemented to prevent unauthorized access and modification of system components and that system and communications protection measures are implemented to prevent unauthorized access and modification of system components.",
#     "page": 6,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control (SC-37) does not appear to be directly supported by the provided source text. The source text discusses account management and temporary/emergency account handling, but does not explicitly address system and communications protection measures to prevent unauthorized access and modification of system components, which is the focus of the claimed control.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AC-19",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'ACCESS ENFORCEMENT' (ID: AC-19) is not explicitly stated in the source text. The source text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not mention AC-19 specifically. Additionally, the description provided for the claimed control is not found in the source text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AC-21",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID AC-21 is not explicitly mentioned or referenced in the provided source text. The text discusses AC-3, which is about 'ACCESS ENFORCEMENT', but does not provide a detailed description for AC-21. Additionally, there is no mention of any control enhancements or specific details that would align with AC-21.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AC-22",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID AC-22 is not explicitly mentioned or referenced in the provided source text. The text discusses AC-3, which is about 'ACCESS ENFORCEMENT', but does not provide a detailed description for AC-22. Additionally, there is no mention of any control enhancements or specific details that would align with AC-22.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AC-25",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID AC-25 is not explicitly mentioned in the source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a detailed description for AC-25. Additionally, there is no mention of a control titled 'ACCESS ENFORCEMENT' being divided into multiple sub-controls like AC-25 in the provided text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "AT-2",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID 'AT-2' does not appear in the provided source text. The source text discusses 'ACCESS ENFORCEMENT' under control AC-3, but there is no mention of a control with ID 'AT-2'. Additionally, the description provided for 'AT-2' is not found in the text and seems to be a generic description of access enforcement rather than a specific control.",
#       "confidence_score": 9
#     }
#   },
#   {
#     "control_id": "AT-3",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID 'AT-3' does not appear in the provided source text. The closest relevant control discussed is 'AC-3 ACCESS ENFORCEMENT', which is described in detail. The term 'AT-3' is not mentioned or referenced in the text.",
#       "confidence_score": 10
#     }
#   },
#   {
#     "control_id": "AU-9",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control AU-9 is not explicitly mentioned or supported in the provided source text. The closest related control is AC-3, which discusses enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of AU-9 in the text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "CA-9",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'CA-9' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not mention 'CA-9' specifically. The description of 'CA-9' is implied rather than stated directly.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "CM-11",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'CM-11' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'CM-11'. Additionally, there is no explicit description of 'CM-11' in the given text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "IA-6",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID 'IA-6' is not explicitly mentioned or referenced in the provided source text. The closest related control is 'AC-3', which discusses access enforcement but does not specifically mention 'IA-6'. The description of 'IA-6' is implied rather than explicitly stated in the text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "IA-7",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID 'IA-7' is not explicitly mentioned or referenced in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a specific description for 'IA-7'. The description of 'IA-7' is implied rather than explicitly stated in the text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "IA-11",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID 'IA-11' is not explicitly mentioned or referenced in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a specific control titled 'IA-11'. The description of 'IA-11' is not found in the given text, and the text does not imply the existence of such a control.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "MA-4",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'MA-4 ACCESS ENFORCEMENT' is not explicitly mentioned or supported in the provided source text. The closest related control discussed is 'AC-3 ACCESS ENFORCEMENT', which focuses on enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of 'MA-4' or any control with a similar title or description in the given text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "MP-4",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID MP-4 is not explicitly mentioned or referenced in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not provide a specific description for a control with ID MP-4. Additionally, the description provided for the claimed control is not found in the text and seems to be inferred rather than explicitly stated.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "PM-2",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'PM-2' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'PM-2'. Additionally, the description of the claimed control is not found in the text and appears to be a generic title rather than a specific control.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "PS-3",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'PS-3' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference a specific control 'PS-3'. The description of 'ACCESS ENFORCEMENT' is implied rather than explicitly stated as a separate control.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SA-17",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SA-17' is not explicitly mentioned or referenced in the provided source text. The closest related control discussed is 'AC-3', which focuses on enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of 'SA-17' or any control with a similar title or description in the given text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-2",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SC-2' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under the control AC-3, but does not reference 'SC-2'. Additionally, there is no explicit description of 'SC-2' in the given text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-3",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SC-3 ACCESS ENFORCEMENT' is not explicitly mentioned or supported in the provided source text. The closest related content is found in the 'AC-3 ACCESS ENFORCEMENT' section, which discusses enforcing approved authorizations for logical access to information and system resources. The term 'SC-3' does not appear in the source text and there is no explicit reference to 'ACCESS ENFORCEMENT' under the 'SC' category.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-4",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SC-4 ACCESS ENFORCEMENT' is not explicitly mentioned or supported in the provided source text. The closest related control discussed is 'AC-3 ACCESS ENFORCEMENT', which focuses on enforcing approved authorizations for logical access to information and system resources. There is no explicit mention of 'SC-4' or any control with a similar title or description in the given text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-28",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SC-28' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'SC-28'. Additionally, the description of 'ACCESS ENFORCEMENT' is implied rather than explicitly stated as a separate control.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-31",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SC-31' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not reference 'SC-31'. Additionally, the description of 'ACCESS ENFORCEMENT' is broad and does not specifically align with the detailed requirements of 'SC-31'.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SC-34",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SC-34' titled 'ACCESS ENFORCEMENT' is not explicitly stated or supported in the provided source text. The source text discusses 'AC-3 ACCESS ENFORCEMENT' and related controls, but does not mention 'SC-34'. The description of 'ACCESS ENFORCEMENT' in the source text is more aligned with 'AC-3' rather than 'SC-34'.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SI-4",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SI-4' is not explicitly mentioned or supported in the provided source text. The text discusses 'AC-3 ACCESS ENFORCEMENT' and mentions 'SI-4' in the context of related controls, but does not describe 'SI-4' as an independent control. Therefore, the claimed control cannot be validated based on the given text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "SI-8",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Not explicitly stated but implied as part of the AC-3 discussion.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control 'SI-8' is not explicitly mentioned or supported in the provided source text. The text discusses 'ACCESS ENFORCEMENT' under control AC-3, but does not mention 'SI-8'. The description of the claimed control is implied rather than explicitly stated in the text.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "CP-9",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Enforce dual authorization for [Assignment: organization-defined privileged commands and/or other organization-defined actions].",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID CP-9 and title 'ACCESS ENFORCEMENT' do not match the content in the source text. The source text discusses 'ACCESS ENFORCEMENT' under a different control ID (AC-3) and does not mention CP-9 or dual authorization for privileged commands under that section.",
#       "confidence_score": 8
#     }
#   },
#   {
#     "control_id": "MP-6",
#     "control_title": "ACCESS ENFORCEMENT",
#     "control_desc": "Dual authorization mechanisms reduce risk related to insider threats.",
#     "page": 9,
#     "validation": {
#       "is_valid": false,
#       "reason": "The claimed control ID MP-6 and title 'ACCESS ENFORCEMENT' does not match any control in the provided source text. The closest related control is AC-6, which discusses dual authorization, but it is noted that this has been incorporated into AC-6. The claimed control description is also not found in the source text.",
#       "confidence_score": 8
#     }
#   }
# ]
