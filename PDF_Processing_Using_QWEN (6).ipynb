# %%
# !pip install -q pdfplumber
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# pdf_path = "/content/drive/MyDrive/pdf_processing/ISO_27001.pdf"
pdf_path = "uploads/test_file_1.pdf"
# pdf_path = "/content/drive/MyDrive/pdf_processing/test_file_2_short.pdf"

# %%
import pypdf
import pdfplumber

# %%
reader = pypdf.PdfReader(pdf_path)

# %%
text_page = []
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages[-20:]:
        normalize_text(text_page.append(page.extract_text(layout=True,x_tolerance=3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 with pdfplumber.open(pdf_path) as pdf:
#       3     for page in pdf.pages[-20:]:
# ----> 4         normalize_text(text_page.append(page.extract_text(layout=True,x_tolerance=3)))
#
# NameError: name 'normalize_text' is not defined

# %%
print(normalize_text(text_page[-20]))
# Out:
# NIST SP 800-53, REV. 5     SECURITY AND PRIVACY CONTROLS FOR INFORMATION SYSTEMS AND ORGANIZATIONS
# _________________________________________________________________________________________________
# This
# publication
# is
# available
# free
# of
# charge
# from:
# TABLE C-10: MEDIA PROTECTION FAMILY
# CONTROL         CONTROL NAME           IMPLEMENTED ASSURANCE
# NUMBER
# CONTROL ENHANCEMENT NAME   BY
# MP-1   Policy and Procedures               O         √
# MP-2   Media Access                        O
# MP-2(1) AUTOMATED RESTRICTED ACCESS    W: Incorporated into MP-4(2).
# MP-2(2) CRYPTOGRAPHIC PROTECTION       W: Incorporated into SC-28(1).
# MP-3   Media Marking                       O
# MP-4   Media Storage                       O
# MP-4(1) CRYPTOGRAPHIC PROTECTION       W: Incorporated into SC-28(1).
# MP-4(2) AUTOMATED RESTRICTED ACCESS        O
# MP-5   Media Transport                     O
# MP-5(1) PROTECTION OUTSIDE OF CONTROLLED AREAS W: Incorporated into MP-5.
# MP-5(2) DOCUMENTATION OF ACTIVITIES    W: Incorporated into MP-5.
# MP-5(3) CUSTODIANS                         O
# MP-5(4) CRYPTOGRAPHIC PROTECTION       W: Incorporated into SC-28(1).
# MP-6   Media Sanitization                  O
# MP-6(1) REVIEW, APPROVE, TRACK, DOCUMENT, AND VERIFY O
# MP-6(2) EQUIPMENT TESTING                  O
# MP-6(3) NONDESTRUCTIVE TECHNIQUES          O
# MP-6(4) CONTROLLED UNCLASSIFIED INFORMATION W: Incorporated into MP-6.
# MP-6(5) CLASSIFIED INFORMATION         W: Incorporated into MP-6.
# MP-6(6) MEDIA DESTRUCTION              W: Incorporated into MP-6.
# MP-6(7) DUAL AUTHORIZATION                 O
# MP-6(8) REMOTE PURGING OR WIPING OF INFORMATION O
# MP-7   Media Use                           O
# MP-7(1) PROHIBIT USE WITHOUT OWNER     W: Incorporated into MP-7.
# MP-7(2) PROHIBIT USE OF SANITIZATION-RESISTANT MEDIA O
# MP-8   Media Downgrading                   O
# MP-8(1) DOCUMENTATION OF PROCESS           O
# MP-8(2) EQUIPMENT TESTING                  O
# MP-8(3) CONTROLLED UNCLASSIFIED INFORMATION O
# MP-8(4) CLASSIFIED INFORMATION             O

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig,pipeline

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
# model_id = "meta-llama/Meta-Llama-3-8B-Instruct" # not using this as it requires login in hugging_face
model_id = "Qwen/Qwen2.5-7B-Instruct"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import re
def normalize_text(raw_text):

    # checking for empty string incase pdf has some
    if not raw_text:
        return ""

    # splitting lines
    lines = raw_text.split('\n')
    cleaned_lines = []

    # Generic noise patterns found the pdf[nist and iso]
    # defining the list because incase new patterns need to be added based on the pdf file.
    # These are safe to remove from ANY document.
    # We include a length check (len < 30) to ensure we don't accidentally
    # delete a real control that happens to contain the word "Page".
    noise_patterns = [
        r"^Page\s+\d+$",               # Matches "Page 1"
        r"^Page\s+\d+\s+of\s+\d+$",    # Matches "Page 1 of 10"
        r"^\d+\s+of\s+\d+$",           # Matches "1 of 10"
        r"^https?://",                 # URL artifacts often in footers
        r"^www\.",                     # Web links
        r"^\(c\)\s+\d{4}",             # Copyright markers like "(c) 2023"
        r"^Copyright",                 # Copyright word
        r'\bAppendix\s+[A-Z]+\s+Page\s+\d+\b'
    ]

    for line in lines:
        line = line.strip()

        # Skip empty lines
        if not line:
            continue

        # Check if line is noise
        is_noise = False
        # Only check short lines to be safe. If a line is 100 chars long,
        # it's likely content, even if it has "Page" in it.
    
        for pattern in noise_patterns:
            if re.search(pattern, line, re.IGNORECASE):
                is_noise = True
                break

        if not is_noise:
            cleaned_lines.append(line)

    # Merging all the lines into one text
    # We join with '\n' to preserve the structure.
    # The LLM needs to see the newlines to understand the layout.
    return '\n'.join(cleaned_lines)

# %%
text_page = []

for page in reader.pages:
    page_cleaned = normalize_text(page.extract_text())
    text_page.append(page_cleaned)

# %%
def clean_and_validate_json(json):
    indices_to_remove = []
    seen_ids = set()
    for idx,control in enumerate(json):
        empty_string_type = ['','none',' ',None]
        if control['control_id'].lower() not in seen_ids:
            seen_ids.add(control['control_id'].lower())
        else:
            indices_to_remove.append(idx)
            continue
        if len(control['control_desc'])<3:
            indices_to_remove.append(idx)
            continue
        try:
            if control['control_id'].lower() in empty_string_type or control['control_title'].lower() in empty_string_type or control['control_desc'].lower() in empty_string_type:
                indices_to_remove.append(idx)
                continue
        except:
            # if it fails to find any one of the column in the json
            indices_to_remove.append(idx)
    json = [element for index, element in enumerate(json) if index not in indices_to_remove]
    return json

# %%
# Cell 5: Define the Extraction Logic

def extract_controls_from_page(page_text):
    # 1. The System Prompt (The Brains)
    system_prompt = """
    You are an expert Compliance Auditor specialized in ISO, NIST, and Regulatory frameworks.

    Task: Extract individual controls or regulatory requirements from the provided text. Ignore all boilerplate, headers, and irrelevant legal prose.

    Control ID Identification Logic:
    Identify control IDs using a pattern-matching approach for:
    1. Annex A style (e.g., A.5.1, A.12.1.1)
    2. NIST style (e.g., AC-1, PM-10)
    3. Legislative/Section style (e.g., Sec. 302, Sec. 404)

    Rules:
    - If controls are found, return ONLY a raw JSON list of objects.
    - Fields:
        - "control_id": The exact identifier (e.g., "Sec. 404", "A.5.1", or "AC-1").
        - "control_title": A concise title (5-10 words) as stated in the text.
        - "control_desc": The full description or specific requirement associated with that ID.
    - If NO controls are found, output strictly: []
    - Strict Formatting: No markdown, no "```json" blocks, no preamble. Just the raw JSON.
    """

    # 2. Structure the Chat
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"Analyze this text:\n\n{page_text}"}
    ]

    # 3. Prepare Inputs
    input_ids = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to(model.device)

    # 4. Generate
    outputs = model.generate(
        input_ids,
        max_new_tokens=4096,      # Limit output size to save time
        do_sample=False,         
        temperature=.1,          #so the model halluinates less
    )

    # 5. Decode
    response = tokenizer.decode(outputs[0][input_ids.shape[-1]:], skip_special_tokens=True)
    return response.strip()

# %% [markdown]
# # Main Extraction Loop
# - the extraction loop gives the whole page chunk to the LLM, and LLM then returns the json output in a snippet

# %%
import json
import time

all_extracted_data = []
responses = []

total_start_time = time.time()  # Start global timer
print("Starting extraction...")

for i, page_text in enumerate(text_page):
    print(f"--- Processing Page {i+1} ---")


    page_start_time = time.time()


    raw_response = extract_controls_from_page(page_text)


    clean_json_string = raw_response.replace("```json", "").replace("```", "").strip()

    page_end_time = time.time()
    elapsed_time = page_end_time - page_start_time
    print(f"   > Time taken: {elapsed_time:.2f} seconds")
    responses.append(clean_json_string)

    try:

        if not clean_json_string or clean_json_string == "[]":
            print(f"   > No controls found.")
            continue

        data = json.loads(clean_json_string)

        # Verify it's a list
        if isinstance(data, list):
            count = len(data)
            print(f"   > Success! Found {count} controls.")
            all_extracted_data.extend(data)
        else:
            print(f"   > Warning: Model returned valid JSON but not a list.")

    except json.JSONDecodeError:
        print(f"   > Error: Model output invalid JSON.\n   > Raw Output: {raw_response[:50]}...")

total_end_time = time.time()
total_duration = total_end_time - total_start_time
minutes = int(total_duration // 60)
seconds = int(total_duration % 60)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Starting extraction...
# --- Processing Page 1 ---
#    > Time taken: 20.01 seconds
#    > Success! Found 30 controls.
# --- Processing Page 2 ---
#    > Time taken: 33.09 seconds
#    > Success! Found 42 controls.
# --- Processing Page 3 ---
#    > Time taken: 12.08 seconds
#    > Success! Found 17 controls.
# --- Processing Page 4 ---
#    > Time taken: 12.00 seconds
#    > Success! Found 17 controls.
# --- Processing Page 5 ---
#    > Time taken: 25.76 seconds
#    > Success! Found 37 controls.
# --- Processing Page 6 ---
#    > Time taken: 12.39 seconds
#    > Success! Found 18 controls.
# --- Processing Page 7 ---
#    > Time taken: 13.45 seconds
#    > Success! Found 21 controls.
# --- Processing Page 8 ---
#    > Time taken: 18.41 seconds
#    > Success! Found 26 controls.
# --- Processing Page 9 ---
#    > Time taken: 28.77 seconds
#    > Success! Found 42 controls.
# --- Processing Page 10 ---
#    > Time taken: 33.31 seconds
#    > Success! Found 43 controls.
# --- Processing Page 11 ---
#    > Time taken: 39.49 seconds
#    > Success! Found 42 controls.
# --- Processing Page 12 ---
#    > Time taken: 11.98 seconds
#    > Success! Found 17 controls.
# --- Processing Page 13 ---
#    > Time taken: 34.24 seconds
#    > Success! Found 41 controls.
# --- Processing Page 14 ---
#    > Time taken: 38.49 seconds
#    > Success! Found 43 controls.
# --- Processing Page 15 ---
#    > Time taken: 34.39 seconds
#    > Success! Found 39 controls.
# --- Processing Page 16 ---
#    > Time taken: 26.54 seconds
#    > Success! Found 39 controls.
# --- Processing Page 17 ---
#    > Time taken: 35.42 seconds
#    > Success! Found 41 controls.
# --- Processing Page 18 ---
#    > Time taken: 34.17 seconds
#    > Success! Found 43 controls.
# --- Processing Page 19 ---
#    > Time taken: 22.21 seconds
#    > Success! Found 30 controls.
# --- Processing Page 20 ---
#    > Time taken: 19.06 seconds
#    > Success! Found 27 controls.

# %%
clean_json_string = clean_and_validate_json(all_extracted_data)

print("\nDONE!")
print(f"Total controls found: {len(all_extracted_data)}")
print(f"Controls After cleaning and removing duplicates: {len(clean_json_string)}")
# Out:
# DONE!
# Total controls found: 633
# Controls After cleaning and removing duplicates: 583

# %%
print(json.dumps(clean_json_string, indent=2))
# Out:
# [
#   {
#     "control_id": "MP-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures"
#   },
#   {
#     "control_id": "MP-2",
#     "control_title": "Media Access",
#     "control_desc": "Media Access"
#   },
#   {
#     "control_id": "MP-2(1)",
#     "control_title": "Automated Restricted Access",
#     "control_desc": "Automated Restricted Access"
#   },
#   {
#     "control_id": "MP-2(2)",
#     "control_title": "Cryptographic Protection",
#     "control_desc": "Cryptographic Protection"
#   },
#   {
#     "control_id": "MP-3",
#     "control_title": "Media Marking",
#     "control_desc": "Media Marking"
#   },
#   {
#     "control_id": "MP-4",
#     "control_title": "Media Storage",
#     "control_desc": "Media Storage"
#   },
#   {
#     "control_id": "MP-4(1)",
#     "control_title": "Cryptographic Protection",
#     "control_desc": "Cryptographic Protection"
#   },
#   {
#     "control_id": "MP-4(2)",
#     "control_title": "Automated Restricted Access",
#     "control_desc": "Automated Restricted Access"
#   },
#   {
#     "control_id": "MP-5",
#     "control_title": "Media Transport",
#     "control_desc": "Media Transport"
#   },
#   {
#     "control_id": "MP-5(1)",
#     "control_title": "Protection Outside of Controlled Areas",
#     "control_desc": "Protection Outside of Controlled Areas"
#   },
#   {
#     "control_id": "MP-5(2)",
#     "control_title": "Documentation of Activities",
#     "control_desc": "Documentation of Activities"
#   },
#   {
#     "control_id": "MP-5(3)",
#     "control_title": "Custodians",
#     "control_desc": "Custodians"
#   },
#   {
#     "control_id": "MP-5(4)",
#     "control_title": "Cryptographic Protection",
#     "control_desc": "Cryptographic Protection"
#   },
#   {
#     "control_id": "MP-6",
#     "control_title": "Media Sanitization",
#     "control_desc": "Media Sanitization"
#   },
#   {
#     "control_id": "MP-6(1)",
#     "control_title": "Review, Approve, Track, Document, and Verify",
#     "control_desc": "Review, Approve, Track, Document, and Verify"
#   },
#   {
#     "control_id": "MP-6(2)",
#     "control_title": "Equipment Testing",
#     "control_desc": "Equipment Testing"
#   },
#   {
#     "control_id": "MP-6(3)",
#     "control_title": "Nondestructive Techniques",
#     "control_desc": "Nondestructive Techniques"
#   },
#   {
#     "control_id": "MP-6(4)",
#     "control_title": "Controlled Unclassified Information",
#     "control_desc": "Controlled Unclassified Information"
#   },
#   {
#     "control_id": "MP-6(5)",
#     "control_title": "Classified Information",
#     "control_desc": "Classified Information"
#   },
#   {
#     "control_id": "MP-6(6)",
#     "control_title": "Media Destruction",
#     "control_desc": "Media Destruction"
#   },
#   {
#     "control_id": "MP-6(7)",
#     "control_title": "Dual Authorization",
#     "control_desc": "Dual Authorization"
#   },
#   {
#     "control_id": "MP-6(8)",
#     "control_title": "Remote Purging or Wiping of Information",
#     "control_desc": "Remote Purging or Wiping of Information"
#   },
#   {
#     "control_id": "MP-7",
#     "control_title": "Media Use",
#     "control_desc": "Media Use"
#   },
#   {
#     "control_id": "MP-7(1)",
#     "control_title": "Prohibit Use Without Owner",
#     "control_desc": "Prohibit Use Without Owner"
#   },
#   {
#     "control_id": "MP-7(2)",
#     "control_title": "Prohibit Use of Sanitization-Resistant Media",
#     "control_desc": "Prohibit Use of Sanitization-Resistant Media"
#   },
#   {
#     "control_id": "MP-8",
#     "control_title": "Media Downgrading",
#     "control_desc": "Media Downgrading"
#   },
#   {
#     "control_id": "MP-8(1)",
#     "control_title": "Documentation of Process",
#     "control_desc": "Documentation of Process"
#   },
#   {
#     "control_id": "MP-8(2)",
#     "control_title": "Equipment Testing",
#     "control_desc": "Equipment Testing"
#   },
#   {
#     "control_id": "MP-8(3)",
#     "control_title": "Controlled Unclassified Information",
#     "control_desc": "Controlled Unclassified Information"
#   },
#   {
#     "control_id": "MP-8(4)",
#     "control_title": "Classified Information",
#     "control_desc": "Classified Information"
#   },
#   {
#     "control_id": "PE-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures"
#   },
#   {
#     "control_id": "PE-2",
#     "control_title": "Physical Access Authorizations",
#     "control_desc": "Physical Access Authorizations"
#   },
#   {
#     "control_id": "PE-2(1)",
#     "control_title": "Access by Position and Role",
#     "control_desc": "Access by Position and Role"
#   },
#   {
#     "control_id": "PE-2(2)",
#     "control_title": "Two Forms of Identification",
#     "control_desc": "Two Forms of Identification"
#   },
#   {
#     "control_id": "PE-2(3)",
#     "control_title": "Restrict Unescorted Access",
#     "control_desc": "Restrict Unescorted Access"
#   },
#   {
#     "control_id": "PE-3",
#     "control_title": "Physical Access Control",
#     "control_desc": "Physical Access Control"
#   },
#   {
#     "control_id": "PE-3(1)",
#     "control_title": "System Access",
#     "control_desc": "System Access"
#   },
#   {
#     "control_id": "PE-3(2)",
#     "control_title": "Facility and Systems",
#     "control_desc": "Facility and Systems"
#   },
#   {
#     "control_id": "PE-3(3)",
#     "control_title": "Continuous Guards",
#     "control_desc": "Continuous Guards"
#   },
#   {
#     "control_id": "PE-3(4)",
#     "control_title": "Lockable Casings",
#     "control_desc": "Lockable Casings"
#   },
#   {
#     "control_id": "PE-3(5)",
#     "control_title": "Tamper Protection",
#     "control_desc": "Tamper Protection"
#   },
#   {
#     "control_id": "PE-3(6)",
#     "control_title": "Facility Penetration Testing",
#     "control_desc": "Facility Penetration Testing"
#   },
#   {
#     "control_id": "PE-3(7)",
#     "control_title": "Physical Barriers",
#     "control_desc": "Physical Barriers"
#   },
#   {
#     "control_id": "PE-3(8)",
#     "control_title": "Access Control Vestibules",
#     "control_desc": "Access Control Vestibules"
#   },
#   {
#     "control_id": "PE-4",
#     "control_title": "Access Control for Transmission",
#     "control_desc": "Access Control for Transmission"
#   },
#   {
#     "control_id": "PE-5",
#     "control_title": "Access Control for Output Devices",
#     "control_desc": "Access Control for Output Devices"
#   },
#   {
#     "control_id": "PE-5(1)",
#     "control_title": "Access to Output by Authorized Individuals",
#     "control_desc": "Access to Output by Authorized Individuals"
#   },
#   {
#     "control_id": "PE-5(2)",
#     "control_title": "Link to Individual Identity",
#     "control_desc": "Link to Individual Identity"
#   },
#   {
#     "control_id": "PE-5(3)",
#     "control_title": "Marking Output Devices",
#     "control_desc": "Marking Output Devices"
#   },
#   {
#     "control_id": "PE-6",
#     "control_title": "Monitoring Physical Access",
#     "control_desc": "Monitoring Physical Access"
#   },
#   {
#     "control_id": "PE-6(1)",
#     "control_title": "Intrusion Alarms and Surveillance Equipment",
#     "control_desc": "Intrusion Alarms and Surveillance Equipment"
#   },
#   {
#     "control_id": "PE-6(2)",
#     "control_title": "Automated Intrusion Recognition and Responses",
#     "control_desc": "Automated Intrusion Recognition and Responses"
#   },
#   {
#     "control_id": "PE-6(3)",
#     "control_title": "Video Surveillance",
#     "control_desc": "Video Surveillance"
#   },
#   {
#     "control_id": "PE-6(4)",
#     "control_title": "Monitoring Physical Access to Systems",
#     "control_desc": "Monitoring Physical Access to Systems"
#   },
#   {
#     "control_id": "PE-7",
#     "control_title": "Visitor Control",
#     "control_desc": "Visitor Control"
#   },
#   {
#     "control_id": "PE-8",
#     "control_title": "Visitor Access Records",
#     "control_desc": "Visitor Access Records"
#   },
#   {
#     "control_id": "PE-8(1)",
#     "control_title": "Automated Records Maintenance and Review",
#     "control_desc": "Automated Records Maintenance and Review"
#   },
#   {
#     "control_id": "PE-8(2)",
#     "control_title": "Physical Access Records",
#     "control_desc": "Physical Access Records"
#   },
#   {
#     "control_id": "PE-8(3)",
#     "control_title": "Limit Personally Identifiable Information Elements",
#     "control_desc": "Limit Personally Identifiable Information Elements"
#   },
#   {
#     "control_id": "PE-9",
#     "control_title": "Power Equipment and Cabling",
#     "control_desc": "Power Equipment and Cabling"
#   },
#   {
#     "control_id": "PE-9(1)",
#     "control_title": "Redundant Cabling",
#     "control_desc": "Redundant Cabling"
#   },
#   {
#     "control_id": "PE-9(2)",
#     "control_title": "Automatic Voltage Controls",
#     "control_desc": "Automatic Voltage Controls"
#   },
#   {
#     "control_id": "PE-10",
#     "control_title": "Emergency Shutoff",
#     "control_desc": "Emergency Shutoff"
#   },
#   {
#     "control_id": "PE-10(1)",
#     "control_title": "Accidental and Unauthorized Activation",
#     "control_desc": "Accidental and Unauthorized Activation"
#   },
#   {
#     "control_id": "PE-11",
#     "control_title": "Emergency Power",
#     "control_desc": "Emergency Power"
#   },
#   {
#     "control_id": "PE-11(1)",
#     "control_title": "Alternate Power Supply \u2014 Minimal Operational Capability",
#     "control_desc": "Alternate Power Supply \u2014 Minimal Operational Capability"
#   },
#   {
#     "control_id": "PE-11(2)",
#     "control_title": "Alternate Power Supply \u2014 Self-Contained",
#     "control_desc": "Alternate Power Supply \u2014 Self-Contained"
#   },
#   {
#     "control_id": "PE-12",
#     "control_title": "Emergency Lighting",
#     "control_desc": "Emergency Lighting"
#   },
#   {
#     "control_id": "PE-12(1)",
#     "control_title": "Essential Mission and Business Functions",
#     "control_desc": "Essential Mission and Business Functions"
#   },
#   {
#     "control_id": "PE-13",
#     "control_title": "Fire Protection",
#     "control_desc": "Fire Protection"
#   },
#   {
#     "control_id": "PE-13(1)",
#     "control_title": "Detection Systems \u2014 Automatic Activation and Notification",
#     "control_desc": "Detection Systems \u2014 Automatic Activation and Notification"
#   },
#   {
#     "control_id": "PE-13(2)",
#     "control_title": "Suppression Systems \u2014 Automatic Activation and Notification",
#     "control_desc": "Suppression Systems \u2014 Automatic Activation and Notification"
#   },
#   {
#     "control_id": "PE-13(3)",
#     "control_title": "Automatic Fire Suppression",
#     "control_desc": "Incorporated into PE-13(2)."
#   },
#   {
#     "control_id": "PE-14",
#     "control_title": "Environmental Controls",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-14(1)",
#     "control_title": "Automatic Controls",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-14(2)",
#     "control_title": "Monitoring with Alarms and Notifications",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-15",
#     "control_title": "Water Damage Protection",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-15(1)",
#     "control_title": "Automation Support",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-16",
#     "control_title": "Delivery and Removal",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-17",
#     "control_title": "Alternate Work Site",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-18",
#     "control_title": "Location of System Components",
#     "control_desc": "Facility site moved to PE-23."
#   },
#   {
#     "control_id": "PE-18(1)",
#     "control_title": "Facility Site",
#     "control_desc": "Moved to PE-23."
#   },
#   {
#     "control_id": "PE-19",
#     "control_title": "Information Leakage",
#     "control_desc": "National emissions policies and procedures."
#   },
#   {
#     "control_id": "PE-19(1)",
#     "control_title": "National Emissions Policies and Procedures",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-20",
#     "control_title": "Asset Monitoring and Tracking",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-21",
#     "control_title": "Electromagnetic Pulse Protection",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-22",
#     "control_title": "Component Marking",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PE-23",
#     "control_title": "Facility Location",
#     "control_desc": "Not specified."
#   },
#   {
#     "control_id": "PL-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures"
#   },
#   {
#     "control_id": "PL-2",
#     "control_title": "System Security and Privacy Plans",
#     "control_desc": "System Security and Privacy Plans"
#   },
#   {
#     "control_id": "PL-2(1)",
#     "control_title": "Concept of Operations",
#     "control_desc": "Concept of Operations"
#   },
#   {
#     "control_id": "PL-2(2)",
#     "control_title": "Functional Architecture",
#     "control_desc": "Functional Architecture"
#   },
#   {
#     "control_id": "PL-2(3)",
#     "control_title": "Plan and Coordinate with Other Organizational Entities",
#     "control_desc": "Plan and Coordinate with Other Organizational Entities"
#   },
#   {
#     "control_id": "PL-3",
#     "control_title": "System Security Plan Update",
#     "control_desc": "System Security Plan Update"
#   },
#   {
#     "control_id": "PL-4",
#     "control_title": "Rules of Behavior",
#     "control_desc": "Rules of Behavior"
#   },
#   {
#     "control_id": "PL-4(1)",
#     "control_title": "Social Media and External Site/Application Usage Restrictions",
#     "control_desc": "Social Media and External Site/Application Usage Restrictions"
#   },
#   {
#     "control_id": "PL-5",
#     "control_title": "Privacy Impact Assessment",
#     "control_desc": "Privacy Impact Assessment"
#   },
#   {
#     "control_id": "PL-6",
#     "control_title": "Security-Related Activity Planning",
#     "control_desc": "Security-Related Activity Planning"
#   },
#   {
#     "control_id": "PL-7",
#     "control_title": "Concept of Operations",
#     "control_desc": "Concept of Operations"
#   },
#   {
#     "control_id": "PL-8",
#     "control_title": "Security and Privacy Architectures",
#     "control_desc": "Security and Privacy Architectures"
#   },
#   {
#     "control_id": "PL-8(1)",
#     "control_title": "Defense in Depth",
#     "control_desc": "Defense in Depth"
#   },
#   {
#     "control_id": "PL-8(2)",
#     "control_title": "Supplier Diversity",
#     "control_desc": "Supplier Diversity"
#   },
#   {
#     "control_id": "PL-9",
#     "control_title": "Central Management",
#     "control_desc": "Central Management"
#   },
#   {
#     "control_id": "PL-10",
#     "control_title": "Baseline Selection",
#     "control_desc": "Baseline Selection"
#   },
#   {
#     "control_id": "PL-11",
#     "control_title": "Baseline Tailoring",
#     "control_desc": "Baseline Tailoring"
#   },
#   {
#     "control_id": "PS-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures"
#   },
#   {
#     "control_id": "PS-2",
#     "control_title": "Position Risk Designation",
#     "control_desc": "Position Risk Designation"
#   },
#   {
#     "control_id": "PS-3",
#     "control_title": "Personnel Screening",
#     "control_desc": "Personnel Screening"
#   },
#   {
#     "control_id": "PS-3(1)",
#     "control_title": "CLASSIFIED INFORMATION",
#     "control_desc": "Classified Information"
#   },
#   {
#     "control_id": "PS-3(2)",
#     "control_title": "FORMAL INDOCTRINATION",
#     "control_desc": "Formal Indoctrination"
#   },
#   {
#     "control_id": "PS-3(3)",
#     "control_title": "INFORMATION REQUIRING SPECIAL PROTECTION MEASURES",
#     "control_desc": "Information Requiring Special Protection Measures"
#   },
#   {
#     "control_id": "PS-3(4)",
#     "control_title": "CITIZENSHIP REQUIREMENTS",
#     "control_desc": "Citizenship Requirements"
#   },
#   {
#     "control_id": "PS-4",
#     "control_title": "Personnel Termination",
#     "control_desc": "Personnel Termination"
#   },
#   {
#     "control_id": "PS-4(1)",
#     "control_title": "POST-EMPLOYMENT REQUIREMENTS",
#     "control_desc": "Post-Employment Requirements"
#   },
#   {
#     "control_id": "PS-4(2)",
#     "control_title": "AUTOMATED ACTIONS",
#     "control_desc": "Automated Actions"
#   },
#   {
#     "control_id": "PS-5",
#     "control_title": "Personnel Transfer",
#     "control_desc": "Personnel Transfer"
#   },
#   {
#     "control_id": "PS-6",
#     "control_title": "Access Agreements",
#     "control_desc": "Access Agreements"
#   },
#   {
#     "control_id": "PS-6(1)",
#     "control_title": "INFORMATION REQUIRING SPECIAL PROTECTION",
#     "control_desc": "Information Requiring Special Protection"
#   },
#   {
#     "control_id": "PS-6(2)",
#     "control_title": "CLASSIFIED INFORMATION REQUIRING SPECIAL PROTECTION",
#     "control_desc": "Classified Information Requiring Special Protection"
#   },
#   {
#     "control_id": "PS-6(3)",
#     "control_title": "POST-EMPLOYMENT REQUIREMENTS",
#     "control_desc": "Post-Employment Requirements"
#   },
#   {
#     "control_id": "PS-7",
#     "control_title": "External Personnel Security",
#     "control_desc": "External Personnel Security"
#   },
#   {
#     "control_id": "PS-8",
#     "control_title": "Personnel Sanctions",
#     "control_desc": "Personnel Sanctions"
#   },
#   {
#     "control_id": "PS-9",
#     "control_title": "Position Descriptions",
#     "control_desc": "Position Descriptions"
#   },
#   {
#     "control_id": "PT-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-2",
#     "control_title": "Authority to Process Personally Identifiable Information",
#     "control_desc": "Authority to process personally identifiable information."
#   },
#   {
#     "control_id": "PT-2(1)",
#     "control_title": "Data Tagging",
#     "control_desc": "Data tagging for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-2(2)",
#     "control_title": "Automation",
#     "control_desc": "Automation for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-3",
#     "control_title": "Personally Identifiable Information Processing Purposes",
#     "control_desc": "Processing purposes for personally identifiable information."
#   },
#   {
#     "control_id": "PT-3(1)",
#     "control_title": "Data Tagging",
#     "control_desc": "Data tagging for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-3(2)",
#     "control_title": "Automation",
#     "control_desc": "Automation for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-4",
#     "control_title": "Consent",
#     "control_desc": "Consent for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-4(1)",
#     "control_title": "Tailored Consent",
#     "control_desc": "Tailored consent for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-4(2)",
#     "control_title": "Just-in-Time Consent",
#     "control_desc": "Just-in-time consent for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-4(3)",
#     "control_title": "Revocation",
#     "control_desc": "Revocation of consent for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-5",
#     "control_title": "Privacy Notice",
#     "control_desc": "Privacy notice for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-5(1)",
#     "control_title": "Just-in-Time Notice",
#     "control_desc": "Just-in-time privacy notice for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-5(2)",
#     "control_title": "Privacy Act Statements",
#     "control_desc": "Privacy act statements for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-6",
#     "control_title": "System of Records Notice",
#     "control_desc": "System of records notice for processing personally identifiable information."
#   },
#   {
#     "control_id": "PT-6(1)",
#     "control_title": "Routine Uses",
#     "control_desc": "Routine uses for system of records notice."
#   },
#   {
#     "control_id": "PT-6(2)",
#     "control_title": "Exemption Rules",
#     "control_desc": "Exemption rules for system of records notice."
#   },
#   {
#     "control_id": "PT-7",
#     "control_title": "Specific Categories of Personally Identifiable Information",
#     "control_desc": "Specific categories of personally identifiable information."
#   },
#   {
#     "control_id": "PT-7(1)",
#     "control_title": "Social Security Numbers",
#     "control_desc": "Social security numbers as a category of personally identifiable information."
#   },
#   {
#     "control_id": "PT-7(2)",
#     "control_title": "First Amendment Information",
#     "control_desc": "First amendment information as a category of personally identifiable information."
#   },
#   {
#     "control_id": "PT-8",
#     "control_title": "Computer Matching Requirements",
#     "control_desc": "Requirements for computer matching of personally identifiable information."
#   },
#   {
#     "control_id": "RA-3",
#     "control_title": "Risk Assessment",
#     "control_desc": "Risk Assessment"
#   },
#   {
#     "control_id": "RA-3(1)",
#     "control_title": "Supply Chain Risk Assessment",
#     "control_desc": "Supply Chain Risk Assessment"
#   },
#   {
#     "control_id": "RA-3(2)",
#     "control_title": "Use of All-Source Intelligence",
#     "control_desc": "Use of All-Source Intelligence"
#   },
#   {
#     "control_id": "RA-3(3)",
#     "control_title": "Dynamic Threat Awareness",
#     "control_desc": "Dynamic Threat Awareness"
#   },
#   {
#     "control_id": "RA-3(4)",
#     "control_title": "Predictive Cyber Analytics",
#     "control_desc": "Predictive Cyber Analytics"
#   },
#   {
#     "control_id": "RA-4",
#     "control_title": "Risk Assessment Update",
#     "control_desc": "Risk Assessment Update"
#   },
#   {
#     "control_id": "RA-5",
#     "control_title": "Vulnerability Monitoring and Scanning",
#     "control_desc": "Vulnerability Monitoring and Scanning"
#   },
#   {
#     "control_id": "RA-5(1)",
#     "control_title": "Update Tool Capability",
#     "control_desc": "Update Tool Capability"
#   },
#   {
#     "control_id": "RA-5(2)",
#     "control_title": "Update Vulnerabilities to be Scanned",
#     "control_desc": "Update Vulnerabilities to be Scanned"
#   },
#   {
#     "control_id": "RA-5(3)",
#     "control_title": "Breadth and Depth of Coverage",
#     "control_desc": "Breadth and Depth of Coverage"
#   },
#   {
#     "control_id": "RA-5(4)",
#     "control_title": "Discoverable Information",
#     "control_desc": "Discoverable Information"
#   },
#   {
#     "control_id": "RA-5(5)",
#     "control_title": "Privileged Access",
#     "control_desc": "Privileged Access"
#   },
#   {
#     "control_id": "RA-5(6)",
#     "control_title": "Automated Trend Analyses",
#     "control_desc": "Automated Trend Analyses"
#   },
#   {
#     "control_id": "RA-5(7)",
#     "control_title": "Automated Detection and Notification of Unauthorized Components",
#     "control_desc": "Automated Detection and Notification of Unauthorized Components"
#   },
#   {
#     "control_id": "RA-5(8)",
#     "control_title": "Review Historic Audit Logs",
#     "control_desc": "Review Historic Audit Logs"
#   },
#   {
#     "control_id": "RA-5(9)",
#     "control_title": "Penetration Testing and Analyses",
#     "control_desc": "Penetration Testing and Analyses"
#   },
#   {
#     "control_id": "RA-5(10)",
#     "control_title": "Correlate Scanning Information",
#     "control_desc": "Correlate Scanning Information"
#   },
#   {
#     "control_id": "RA-5(11)",
#     "control_title": "Public Disclosure Program",
#     "control_desc": "Public Disclosure Program"
#   },
#   {
#     "control_id": "RA-6",
#     "control_title": "Technical Surveillance Countermeasures Survey",
#     "control_desc": "Technical Surveillance Countermeasures Survey"
#   },
#   {
#     "control_id": "RA-7",
#     "control_title": "Risk Response",
#     "control_desc": "Risk Response"
#   },
#   {
#     "control_id": "RA-8",
#     "control_title": "Privacy Impact Assessments",
#     "control_desc": "Privacy Impact Assessments"
#   },
#   {
#     "control_id": "RA-10",
#     "control_title": "Threat Hunting",
#     "control_desc": "Threat Hunting"
#   },
#   {
#     "control_id": "SA-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures"
#   },
#   {
#     "control_id": "SA-2",
#     "control_title": "Allocation of Resources",
#     "control_desc": "Allocation of Resources"
#   },
#   {
#     "control_id": "SA-3",
#     "control_title": "System Development Life Cycle",
#     "control_desc": "System Development Life Cycle"
#   },
#   {
#     "control_id": "SA-3(1)",
#     "control_title": "Manage Preproduction Environment",
#     "control_desc": "Manage Preproduction Environment"
#   },
#   {
#     "control_id": "SA-3(2)",
#     "control_title": "Use of Live or Operational Data",
#     "control_desc": "Use of Live or Operational Data"
#   },
#   {
#     "control_id": "SA-3(3)",
#     "control_title": "Technology Refresh",
#     "control_desc": "Technology Refresh"
#   },
#   {
#     "control_id": "SA-4",
#     "control_title": "Acquisition Process",
#     "control_desc": "Acquisition Process"
#   },
#   {
#     "control_id": "SA-4(1)",
#     "control_title": "Functional Properties of Controls",
#     "control_desc": "Functional Properties of Controls"
#   },
#   {
#     "control_id": "SA-4(2)",
#     "control_title": "Design and Implementation Information for Controls",
#     "control_desc": "Design and Implementation Information for Controls"
#   },
#   {
#     "control_id": "SA-4(3)",
#     "control_title": "Development Methods, Techniques, and Practices",
#     "control_desc": "Development Methods, Techniques, and Practices"
#   },
#   {
#     "control_id": "SA-4(4)",
#     "control_title": "Assignment of Components to Systems",
#     "control_desc": "Assignment of Components to Systems"
#   },
#   {
#     "control_id": "SA-4(5)",
#     "control_title": "System, Component, and Service Configurations",
#     "control_desc": "System, Component, and Service Configurations"
#   },
#   {
#     "control_id": "SA-4(6)",
#     "control_title": "Use of Information Assurance Products",
#     "control_desc": "Use of Information Assurance Products"
#   },
#   {
#     "control_id": "SA-4(7)",
#     "control_title": "NIAP-Approved Protection Profiles",
#     "control_desc": "NIAP-Approved Protection Profiles"
#   },
#   {
#     "control_id": "SA-4(8)",
#     "control_title": "Continuous Monitoring Plan for Controls",
#     "control_desc": "Continuous Monitoring Plan for Controls"
#   },
#   {
#     "control_id": "SA-4(9)",
#     "control_title": "Functions, Ports, Protocols, and Services in Use",
#     "control_desc": "Functions, Ports, Protocols, and Services in Use"
#   },
#   {
#     "control_id": "SA-4(10)",
#     "control_title": "Use of Approved PIV Products",
#     "control_desc": "Use of Approved PIV Products"
#   },
#   {
#     "control_id": "SA-4(11)",
#     "control_title": "System of Records",
#     "control_desc": "System of Records"
#   },
#   {
#     "control_id": "SA-4(12)",
#     "control_title": "Data Ownership",
#     "control_desc": "Data Ownership"
#   },
#   {
#     "control_id": "SA-5",
#     "control_title": "System Documentation",
#     "control_desc": "System Documentation"
#   },
#   {
#     "control_id": "SA-5(1)",
#     "control_title": "Functional Properties of Security Controls",
#     "control_desc": "Functional Properties of Security Controls"
#   },
#   {
#     "control_id": "SA-5(2)",
#     "control_title": "Security-Relevant External System Interfaces",
#     "control_desc": "Security-Relevant External System Interfaces"
#   },
#   {
#     "control_id": "SA-5(3)",
#     "control_title": "High-Level Design",
#     "control_desc": "High-Level Design"
#   },
#   {
#     "control_id": "SA-5(4)",
#     "control_title": "Low-Level Design",
#     "control_desc": "Low-Level Design"
#   },
#   {
#     "control_id": "SA-5(5)",
#     "control_title": "Source Code",
#     "control_desc": "Source Code"
#   },
#   {
#     "control_id": "SA-6",
#     "control_title": "Software Usage Restrictions",
#     "control_desc": "Software Usage Restrictions"
#   },
#   {
#     "control_id": "SA-7",
#     "control_title": "User-Installed Software",
#     "control_desc": "User-Installed Software"
#   },
#   {
#     "control_id": "SA-8",
#     "control_title": "Security and Privacy Engineering Principles",
#     "control_desc": "Security and Privacy Engineering Principles"
#   },
#   {
#     "control_id": "SA-8(1)",
#     "control_title": "Clear Abstractions",
#     "control_desc": "Clear Abstractions"
#   },
#   {
#     "control_id": "SA-8(2)",
#     "control_title": "Least Common Mechanism",
#     "control_desc": "Least Common Mechanism"
#   },
#   {
#     "control_id": "SA-8(3)",
#     "control_title": "Modularity and Layering",
#     "control_desc": "Modularity and Layering"
#   },
#   {
#     "control_id": "SA-8(4)",
#     "control_title": "Partially Ordered Dependencies",
#     "control_desc": "Partially Ordered Dependencies"
#   },
#   {
#     "control_id": "SA-8(5)",
#     "control_title": "Efficiently Mediated Access",
#     "control_desc": "Efficiently Mediated Access"
#   },
#   {
#     "control_id": "SA-8(6)",
#     "control_title": "Minimized Sharing",
#     "control_desc": "Minimized Sharing"
#   },
#   {
#     "control_id": "SA-8(7)",
#     "control_title": "Reduced Complexity",
#     "control_desc": "Reduced Complexity"
#   },
#   {
#     "control_id": "SA-8(8)",
#     "control_title": "Secure Evolvability",
#     "control_desc": "Secure Evolvability"
#   },
#   {
#     "control_id": "SA-8(9)",
#     "control_title": "Trusted Components",
#     "control_desc": "Trusted Components"
#   },
#   {
#     "control_id": "SA-8(10)",
#     "control_title": "Hierarchical Trust",
#     "control_desc": "Hierarchical Trust"
#   },
#   {
#     "control_id": "SA-8(11)",
#     "control_title": "Inverse Modification Threshold",
#     "control_desc": "Inverse Modification Threshold"
#   },
#   {
#     "control_id": "SA-8(12)",
#     "control_title": "Hierarchical Protection",
#     "control_desc": "Hierarchical Protection"
#   },
#   {
#     "control_id": "SA-8(13)",
#     "control_title": "Minimized Security Elements",
#     "control_desc": "Minimized Security Elements"
#   },
#   {
#     "control_id": "SA-8(14)",
#     "control_title": "Least Privilege",
#     "control_desc": "Least Privilege"
#   },
#   {
#     "control_id": "SA-8(15)",
#     "control_title": "Predicate Permission OS",
#     "control_desc": "Implement predicate permission operating system."
#   },
#   {
#     "control_id": "SA-8(16)",
#     "control_title": "Self-Reliant Trustworthiness",
#     "control_desc": "Ensure self-reliant trustworthiness."
#   },
#   {
#     "control_id": "SA-8(17)",
#     "control_title": "Secure Distributed Composition",
#     "control_desc": "Secure distributed composition."
#   },
#   {
#     "control_id": "SA-8(18)",
#     "control_title": "Trusted Communications Channels",
#     "control_desc": "Trusted communications channels."
#   },
#   {
#     "control_id": "SA-8(20)",
#     "control_title": "Secure Metadata Management",
#     "control_desc": "Secure metadata management."
#   },
#   {
#     "control_id": "SA-8(21)",
#     "control_title": "Self-Analysis",
#     "control_desc": "Self-analysis."
#   },
#   {
#     "control_id": "SA-8(22)",
#     "control_title": "Accountability and Traceability",
#     "control_desc": "Accountability and traceability."
#   },
#   {
#     "control_id": "SA-8(23)",
#     "control_title": "Secure Defaults",
#     "control_desc": "Secure defaults."
#   },
#   {
#     "control_id": "SA-8(24)",
#     "control_title": "Secure Failure and Recovery",
#     "control_desc": "Secure failure and recovery."
#   },
#   {
#     "control_id": "SA-8(25)",
#     "control_title": "Economic Security",
#     "control_desc": "Economic security."
#   },
#   {
#     "control_id": "SA-8(26)",
#     "control_title": "Performance Security",
#     "control_desc": "Performance security."
#   },
#   {
#     "control_id": "SA-8(27)",
#     "control_title": "Human Factored Security",
#     "control_desc": "Human factored security."
#   },
#   {
#     "control_id": "SA-8(28)",
#     "control_title": "Acceptable Security",
#     "control_desc": "Acceptable security."
#   },
#   {
#     "control_id": "SA-8(29)",
#     "control_title": "Repeatable and Documented Procedures",
#     "control_desc": "Repeatable and documented procedures."
#   },
#   {
#     "control_id": "SA-8(30)",
#     "control_title": "Procedural Rigor",
#     "control_desc": "Procedural rigor."
#   },
#   {
#     "control_id": "SA-8(31)",
#     "control_title": "Secure System Modification",
#     "control_desc": "Secure system modification."
#   },
#   {
#     "control_id": "SA-8(32)",
#     "control_title": "Sufficient Documentation",
#     "control_desc": "Sufficient documentation."
#   },
#   {
#     "control_id": "SA-8(33)",
#     "control_title": "Minimization",
#     "control_desc": "Minimization."
#   },
#   {
#     "control_id": "SA-9(1)",
#     "control_title": "Risk Assessments and Organizational Approvals",
#     "control_desc": "Risk assessments and organizational approvals."
#   },
#   {
#     "control_id": "SA-9(2)",
#     "control_title": "Identification of Functions, Ports, Protocols, and Services",
#     "control_desc": "Identification of functions, ports, protocols, and services."
#   },
#   {
#     "control_id": "SA-9(3)",
#     "control_title": "Establish and Maintain Trust Relationship with Providers",
#     "control_desc": "Establish and maintain trust relationship with providers."
#   },
#   {
#     "control_id": "SA-9(4)",
#     "control_title": "Consistent Interests of Consumers and Providers",
#     "control_desc": "Consistent interests of consumers and providers."
#   },
#   {
#     "control_id": "SA-9(5)",
#     "control_title": "Processing, Storage, and Service Location",
#     "control_desc": "Processing, storage, and service location."
#   },
#   {
#     "control_id": "SA-9(6)",
#     "control_title": "Organization-Controlled Cryptographic Keys",
#     "control_desc": "Organization-controlled cryptographic keys."
#   },
#   {
#     "control_id": "SA-9(7)",
#     "control_title": "Organization-Controlled Integrity Checking",
#     "control_desc": "Organization-controlled integrity checking."
#   },
#   {
#     "control_id": "SA-9(8)",
#     "control_title": "Processing and Storage Location - U.S. Jurisdiction",
#     "control_desc": "Processing and storage location - U.S. jurisdiction."
#   },
#   {
#     "control_id": "SA-10(1)",
#     "control_title": "Software and Firmware Integrity Verification",
#     "control_desc": "Software and firmware integrity verification."
#   },
#   {
#     "control_id": "SA-10(2)",
#     "control_title": "Alternative Configuration Management Processes",
#     "control_desc": "Alternative configuration management processes."
#   },
#   {
#     "control_id": "SA-10(3)",
#     "control_title": "Hardware Integrity Verification",
#     "control_desc": "Hardware integrity verification."
#   },
#   {
#     "control_id": "SA-10(4)",
#     "control_title": "Trusted Generation",
#     "control_desc": "Trusted generation."
#   },
#   {
#     "control_id": "SA-10(5)",
#     "control_title": "Mapping Integrity for Version Control",
#     "control_desc": "Mapping integrity for version control."
#   },
#   {
#     "control_id": "SA-10(6)",
#     "control_title": "Trusted Distribution",
#     "control_desc": "Trusted distribution."
#   },
#   {
#     "control_id": "SA-10(7)",
#     "control_title": "Security and Privacy Representatives",
#     "control_desc": "Security and privacy representatives."
#   },
#   {
#     "control_id": "SA-11(1)",
#     "control_title": "Static Code Analysis",
#     "control_desc": "Static code analysis."
#   },
#   {
#     "control_id": "SA-11(2)",
#     "control_title": "Threat Modeling and Vulnerability Analyses",
#     "control_desc": "Threat modeling and vulnerability analyses."
#   },
#   {
#     "control_id": "SA-11(3)",
#     "control_title": "Independent Verification of Assessment Plans and Evidence",
#     "control_desc": "Independent verification of assessment plans and evidence."
#   },
#   {
#     "control_id": "SA-11(4)",
#     "control_title": "Manual Code Reviews",
#     "control_desc": "Manual code reviews."
#   },
#   {
#     "control_id": "SA-11(5)",
#     "control_title": "Penetration Testing",
#     "control_desc": "Penetration testing."
#   },
#   {
#     "control_id": "SA-11(6)",
#     "control_title": "Attack Surface Reviews",
#     "control_desc": "Attack surface reviews."
#   },
#   {
#     "control_id": "SA-11(7)",
#     "control_title": "Verify Scope of Testing and Evaluation",
#     "control_desc": "VERIFY SCOPE OF TESTING AND EVALUATION"
#   },
#   {
#     "control_id": "SA-11(8)",
#     "control_title": "Dynamic Code Analysis",
#     "control_desc": "DYNAMIC CODE ANALYSIS"
#   },
#   {
#     "control_id": "SA-11(9)",
#     "control_title": "Interactive Application Security Testing",
#     "control_desc": "INTERACTIVE APPLICATION SECURITY TESTING"
#   },
#   {
#     "control_id": "SA-12(1)",
#     "control_title": "Acquisition Strategies, Tools, and Methods",
#     "control_desc": "ACQUISITION STRATEGIES, TOOLS, AND METHODS"
#   },
#   {
#     "control_id": "SA-12(2)",
#     "control_title": "Supplier Reviews",
#     "control_desc": "SUPPLIER REVIEWS"
#   },
#   {
#     "control_id": "SA-12(3)",
#     "control_title": "Trusted Shipping and Warehousing",
#     "control_desc": "TRUSTED SHIPPING AND WAREHOUSING"
#   },
#   {
#     "control_id": "SA-12(4)",
#     "control_title": "Diversity of Suppliers",
#     "control_desc": "DIVERSITY OF SUPPLIERS"
#   },
#   {
#     "control_id": "SA-12(5)",
#     "control_title": "Limitation of Harm",
#     "control_desc": "LIMITATION OF HARM"
#   },
#   {
#     "control_id": "SA-12(6)",
#     "control_title": "Minimizing Procurement Time",
#     "control_desc": "MINIMIZING PROCUREMENT TIME"
#   },
#   {
#     "control_id": "SA-12(7)",
#     "control_title": "Assessments Prior to Selection/Acceptance/Update",
#     "control_desc": "ASSessments PRIOR TO SELECTION / ACCEPTANCE / UPDATE"
#   },
#   {
#     "control_id": "SA-12(8)",
#     "control_title": "Use of All-Source Intelligence",
#     "control_desc": "USE OF ALL-SOURCE INTELLIGENCE"
#   },
#   {
#     "control_id": "SA-12(9)",
#     "control_title": "Operations Security",
#     "control_desc": "OPERATIONS SECURITY"
#   },
#   {
#     "control_id": "SA-12(10)",
#     "control_title": "Validate as Genuine and Not Altered",
#     "control_desc": "VALIDATE AS GENUINE AND NOT ALTERED"
#   },
#   {
#     "control_id": "SA-12(11)",
#     "control_title": "Penetration Testing/Analysis of Elements, Processes, and Actors",
#     "control_desc": "PENETRATION TESTING / ANALYSIS OF ELEMENTS, PROCESSES, AND ACTORS"
#   },
#   {
#     "control_id": "SA-12(12)",
#     "control_title": "Inter-Organizational Agreements",
#     "control_desc": "INTER-ORGANIZATIONAL AGREEMENTS"
#   },
#   {
#     "control_id": "SA-12(13)",
#     "control_title": "Critical Information System Components",
#     "control_desc": "CRITICAL INFORMATION SYSTEM COMPONENTS"
#   },
#   {
#     "control_id": "SA-12(14)",
#     "control_title": "Identity and Traceability",
#     "control_desc": "IDENTITY AND TRACEABILITY"
#   },
#   {
#     "control_id": "SA-12(15)",
#     "control_title": "Processes to Address Weaknesses or Deficiencies",
#     "control_desc": "PROCESSES TO ADDRESS WEAKNESSES OR DEFICIENCIES"
#   },
#   {
#     "control_id": "SA-13",
#     "control_title": "Trustworthiness",
#     "control_desc": "Trustworthiness"
#   },
#   {
#     "control_id": "SA-14(1)",
#     "control_title": "Critical Components with No Viable Alternative Sourcing",
#     "control_desc": "CRITICAL COMPONENTS WITH NO VIABLE ALTERNATIVE SOURCING"
#   },
#   {
#     "control_id": "SA-15(1)",
#     "control_title": "Quality Metrics",
#     "control_desc": "QUALITY METRICS"
#   },
#   {
#     "control_id": "SA-15(2)",
#     "control_title": "Security and Privacy Tracking Tools",
#     "control_desc": "SECURITY AND PRIVACY TRACKING TOOLS"
#   },
#   {
#     "control_id": "SA-15(3)",
#     "control_title": "Criticality Analysis",
#     "control_desc": "CRITICALITY ANALYSIS"
#   },
#   {
#     "control_id": "SA-15(4)",
#     "control_title": "Threat Modeling and Vulnerability Analysis",
#     "control_desc": "THREAT MODELING AND VULNERABILITY ANALYSIS"
#   },
#   {
#     "control_id": "SA-15(5)",
#     "control_title": "Attack Surface Reduction",
#     "control_desc": "ATTACK SURFACE REDUCTION"
#   },
#   {
#     "control_id": "SA-15(6)",
#     "control_title": "Continuous Improvement",
#     "control_desc": "CONTINUOUS IMPROVEMENT"
#   },
#   {
#     "control_id": "SA-15(7)",
#     "control_title": "Automated Vulnerability Analysis",
#     "control_desc": "AUTOMATED VULNERABILITY ANALYSIS"
#   },
#   {
#     "control_id": "SA-15(8)",
#     "control_title": "Reuse of Threat and Vulnerability Information",
#     "control_desc": "REUSE OF THREAT AND VULNERABILITY INFORMATION"
#   },
#   {
#     "control_id": "SA-15(9)",
#     "control_title": "Use of Live Data",
#     "control_desc": "USE OF LIVE DATA"
#   },
#   {
#     "control_id": "SA-15(10)",
#     "control_title": "Incident Response Plan",
#     "control_desc": "INCIDENT RESPONSE PLAN"
#   },
#   {
#     "control_id": "SA-15(11)",
#     "control_title": "Archive System or Component",
#     "control_desc": "ARCHIVE SYSTEM OR COMPONENT"
#   },
#   {
#     "control_id": "SA-15(12)",
#     "control_title": "Minimize Personally Identifiable Information",
#     "control_desc": "MINIMIZE PERSONALLY IDENTIFIABLE INFORMATION"
#   },
#   {
#     "control_id": "SA-16",
#     "control_title": "Developer-Provided Training",
#     "control_desc": "DEVELOPER-PROVIDED TRAINING"
#   },
#   {
#     "control_id": "SA-17(1)",
#     "control_title": "Formal Policy Model",
#     "control_desc": "FORMAL POLICY MODEL"
#   },
#   {
#     "control_id": "SA-17(2)",
#     "control_title": "Security-Relevant Components",
#     "control_desc": "SECURITY-RELEVANT COMPONENTS"
#   },
#   {
#     "control_id": "SA-17(3)",
#     "control_title": "Formal Correspondence",
#     "control_desc": "FORMAL CORRESPONDENCE"
#   },
#   {
#     "control_id": "SA-17(4)",
#     "control_title": "Informal Correspondence",
#     "control_desc": "INFORMAL CORRESPONDENCE"
#   },
#   {
#     "control_id": "SA-17(5)",
#     "control_title": "Conceptually Simple Design",
#     "control_desc": "CONCEPTUALLY SIMPLE DESIGN"
#   },
#   {
#     "control_id": "SA-17(6)",
#     "control_title": "Structure for Testing",
#     "control_desc": "Structure for testing"
#   },
#   {
#     "control_id": "SA-17(7)",
#     "control_title": "Least Privilege Structure",
#     "control_desc": "Structure for least privilege"
#   },
#   {
#     "control_id": "SA-17(8)",
#     "control_title": "Orchestration",
#     "control_desc": "Orchestration"
#   },
#   {
#     "control_id": "SA-17(9)",
#     "control_title": "Design Diversity",
#     "control_desc": "Design diversity"
#   },
#   {
#     "control_id": "SA-18",
#     "control_title": "Tamper Resistance and Detection",
#     "control_desc": "Tamper resistance and detection"
#   },
#   {
#     "control_id": "SA-18(1)",
#     "control_title": "Multiple Phases of System Development Lifecycle",
#     "control_desc": "Multiple phases of system development lifecycle"
#   },
#   {
#     "control_id": "SA-18(2)",
#     "control_title": "Inspection of Systems or Components",
#     "control_desc": "Inspection of systems or components"
#   },
#   {
#     "control_id": "SA-19",
#     "control_title": "Component Authenticity",
#     "control_desc": "Component authenticity"
#   },
#   {
#     "control_id": "SA-19(1)",
#     "control_title": "Anti-counterfeit Training",
#     "control_desc": "Anti-counterfeit training"
#   },
#   {
#     "control_id": "SA-19(2)",
#     "control_title": "Configuration Control for Component Service and Repair",
#     "control_desc": "Configuration control for component service and repair"
#   },
#   {
#     "control_id": "SA-19(3)",
#     "control_title": "Component Disposal",
#     "control_desc": "Component disposal"
#   },
#   {
#     "control_id": "SA-19(4)",
#     "control_title": "Anti-counterfeit Scanning",
#     "control_desc": "Anti-counterfeit scanning"
#   },
#   {
#     "control_id": "SA-20",
#     "control_title": "Customized Development of Critical Components",
#     "control_desc": "Customized development of critical components"
#   },
#   {
#     "control_id": "SA-21",
#     "control_title": "Developer Screening",
#     "control_desc": "Developer screening"
#   },
#   {
#     "control_id": "SA-21(1)",
#     "control_title": "Validation of Screening",
#     "control_desc": "Validation of screening"
#   },
#   {
#     "control_id": "SA-22",
#     "control_title": "Unsupported System Components",
#     "control_desc": "Unsupported system components"
#   },
#   {
#     "control_id": "SA-22(1)",
#     "control_title": "Alternative Sources for Continued Support",
#     "control_desc": "Alternative sources for continued support"
#   },
#   {
#     "control_id": "SA-23",
#     "control_title": "Specialization",
#     "control_desc": "Specialization"
#   },
#   {
#     "control_id": "SC-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures"
#   },
#   {
#     "control_id": "SC-2",
#     "control_title": "Separation of System and User Functionality",
#     "control_desc": "Separation of System and User Functionality"
#   },
#   {
#     "control_id": "SC-2(1)",
#     "control_title": "Interfaces for Non-Privileged Users",
#     "control_desc": "Interfaces for Non-Privileged Users"
#   },
#   {
#     "control_id": "SC-2(2)",
#     "control_title": "Disassociability",
#     "control_desc": "Disassociability"
#   },
#   {
#     "control_id": "SC-3",
#     "control_title": "Security Function Isolation",
#     "control_desc": "Security Function Isolation"
#   },
#   {
#     "control_id": "SC-3(1)",
#     "control_title": "Hardware Separation",
#     "control_desc": "Hardware Separation"
#   },
#   {
#     "control_id": "SC-3(2)",
#     "control_title": "Access and Flow Control Functions",
#     "control_desc": "Access and Flow Control Functions"
#   },
#   {
#     "control_id": "SC-3(3)",
#     "control_title": "Minimize Non-Security Functionality Operating System",
#     "control_desc": "Minimize Non-Security Functionality Operating System"
#   },
#   {
#     "control_id": "SC-3(4)",
#     "control_title": "Module Coupling and Cohesiveness",
#     "control_desc": "Module Coupling and Cohesiveness"
#   },
#   {
#     "control_id": "SC-3(5)",
#     "control_title": "Layered Structures",
#     "control_desc": "Layered Structures"
#   },
#   {
#     "control_id": "SC-4",
#     "control_title": "Information in Shared System Resources",
#     "control_desc": "Information in Shared System Resources"
#   },
#   {
#     "control_id": "SC-4(1)",
#     "control_title": "Security Levels",
#     "control_desc": "Security Levels"
#   },
#   {
#     "control_id": "SC-4(2)",
#     "control_title": "Multilevel or Periods Processing",
#     "control_desc": "Multilevel or Periods Processing"
#   },
#   {
#     "control_id": "SC-5",
#     "control_title": "Denial-of-Service Protection",
#     "control_desc": "Denial-of-Service Protection"
#   },
#   {
#     "control_id": "SC-5(1)",
#     "control_title": "Restrict Ability to Attack Other Systems",
#     "control_desc": "Restrict Ability to Attack Other Systems"
#   },
#   {
#     "control_id": "SC-5(2)",
#     "control_title": "Capacity, Bandwidth, and Redundancy",
#     "control_desc": "Capacity, Bandwidth, and Redundancy"
#   },
#   {
#     "control_id": "SC-5(3)",
#     "control_title": "Detection and Monitoring",
#     "control_desc": "Detection and Monitoring"
#   },
#   {
#     "control_id": "SC-6",
#     "control_title": "Resource Availability",
#     "control_desc": "Resource Availability"
#   },
#   {
#     "control_id": "SC-7",
#     "control_title": "Boundary Protection",
#     "control_desc": "Boundary Protection"
#   },
#   {
#     "control_id": "SC-7(1)",
#     "control_title": "Physically Separated Subnetworks",
#     "control_desc": "Physically Separated Subnetworks"
#   },
#   {
#     "control_id": "SC-7(2)",
#     "control_title": "Public Access",
#     "control_desc": "Public Access"
#   },
#   {
#     "control_id": "SC-7(3)",
#     "control_title": "Access Points",
#     "control_desc": "Access Points"
#   },
#   {
#     "control_id": "SC-7(4)",
#     "control_title": "External Telecommunications Services",
#     "control_desc": "External Telecommunications Services"
#   },
#   {
#     "control_id": "SC-7(5)",
#     "control_title": "Deny by Default \u2014 Allow by Exception",
#     "control_desc": "Deny by Default \u2014 Allow by Exception"
#   },
#   {
#     "control_id": "SC-7(6)",
#     "control_title": "Response to Recognized Failures",
#     "control_desc": "Response to Recognized Failures"
#   },
#   {
#     "control_id": "SC-7(7)",
#     "control_title": "Split Tunneling for Remote Devices",
#     "control_desc": "Split Tunneling for Remote Devices"
#   },
#   {
#     "control_id": "SC-7(8)",
#     "control_title": "Route Traffic to Authenticated Proxy Servers",
#     "control_desc": "Route Traffic to Authenticated Proxy Servers"
#   },
#   {
#     "control_id": "SC-7(9)",
#     "control_title": "Restrict Threatening Outgoing Communications Traffic",
#     "control_desc": "Restrict Threatening Outgoing Communications Traffic"
#   },
#   {
#     "control_id": "SC-7(10)",
#     "control_title": "Prevent Exfiltration",
#     "control_desc": "Prevent Exfiltration"
#   },
#   {
#     "control_id": "SC-7(11)",
#     "control_title": "Restrict Incoming Communications Traffic",
#     "control_desc": "Restrict Incoming Communications Traffic"
#   },
#   {
#     "control_id": "SC-7(12)",
#     "control_title": "Host-Based Protection",
#     "control_desc": "Host-Based Protection"
#   },
# ...
#   },
#   {
#     "control_id": "SI-4(17)",
#     "control_title": "INTEGRATED SITUATIONAL AWARENESS",
#     "control_desc": "INTEGRATED SITUATIONAL AWARENESS O \u221a"
#   },
#   {
#     "control_id": "SI-4(18)",
#     "control_title": "ANALYZE TRAFFIC AND COVERT EXFILTRATION",
#     "control_desc": "ANALYZE TRAFFIC AND COVERT EXFILTRATION O/S \u221a"
#   },
#   {
#     "control_id": "SI-4(19)",
#     "control_title": "RISK FOR INDIVIDUALS",
#     "control_desc": "RISK FOR INDIVIDUALS O \u221a"
#   },
#   {
#     "control_id": "SI-4(20)",
#     "control_title": "PRIVILEGED USERS",
#     "control_desc": "PRIVILEGED USERS S \u221a"
#   },
#   {
#     "control_id": "SI-4(21)",
#     "control_title": "PROBATIONARY PERIODS",
#     "control_desc": "PROBATIONARY PERIODS O \u221a"
#   },
#   {
#     "control_id": "SI-4(22)",
#     "control_title": "Unauthorized Network Services",
#     "control_desc": "UNAUTHORIZED NETWORK SERVICES"
#   },
#   {
#     "control_id": "SI-4(23)",
#     "control_title": "Host-Based Devices",
#     "control_desc": "HOST-BASED DEVICES"
#   },
#   {
#     "control_id": "SI-4(24)",
#     "control_title": "Indicators of Compromise",
#     "control_desc": "INDICATORS OF COMPROMISE"
#   },
#   {
#     "control_id": "SI-4(25)",
#     "control_title": "Optimize Network Traffic Analysis",
#     "control_desc": "OPTIMIZE NETWORK TRAFFIC ANALYSIS"
#   },
#   {
#     "control_id": "SI-5",
#     "control_title": "Security Alerts, Advisories, and Directives",
#     "control_desc": "SECURITY ALERTS, ADVISORIES, AND DIRECTIVES"
#   },
#   {
#     "control_id": "SI-5(1)",
#     "control_title": "Automated Alerts and Advisories",
#     "control_desc": "AUTOMATED ALERTS AND ADVISORIES"
#   },
#   {
#     "control_id": "SI-6",
#     "control_title": "Security and Privacy Function Verification",
#     "control_desc": "SECURITY AND PRIVACY FUNCTION VERIFICATION"
#   },
#   {
#     "control_id": "SI-6(1)",
#     "control_title": "Notification of Failed Security Tests",
#     "control_desc": "NOTIFICATION OF FAILED SECURITY TESTS"
#   },
#   {
#     "control_id": "SI-6(2)",
#     "control_title": "Automation Support for Distributed Testing",
#     "control_desc": "AUTOMATION SUPPORT FOR DISTRIBUTED TESTING"
#   },
#   {
#     "control_id": "SI-6(3)",
#     "control_title": "Report Verification Results",
#     "control_desc": "REPORT VERIFICATION RESULTS"
#   },
#   {
#     "control_id": "SI-7",
#     "control_title": "Software, Firmware, and Information Integrity",
#     "control_desc": "SOFTWARE, FIRMWARE, AND INFORMATION INTEGRITY"
#   },
#   {
#     "control_id": "SI-7(1)",
#     "control_title": "Integrity Checks",
#     "control_desc": "INTEGRITY CHECKS"
#   },
#   {
#     "control_id": "SI-7(2)",
#     "control_title": "Automated Notifications of Integrity Violations",
#     "control_desc": "AUTOMATED NOTIFICATIONS OF INTEGRITY VIOLATIONS"
#   },
#   {
#     "control_id": "SI-7(3)",
#     "control_title": "Centrally Managed Integrity Tools",
#     "control_desc": "CENTRALLY MANAGED INTEGRITY TOOLS"
#   },
#   {
#     "control_id": "SI-7(4)",
#     "control_title": "Tamper-Evident Packaging",
#     "control_desc": "TAMPER-EVIDENT PACKAGING"
#   },
#   {
#     "control_id": "SI-7(5)",
#     "control_title": "Automated Response to Integrity Violations",
#     "control_desc": "AUTOMATED RESPONSE TO INTEGRITY VIOLATIONS"
#   },
#   {
#     "control_id": "SI-7(6)",
#     "control_title": "Cryptography Protection",
#     "control_desc": "CRYPTOGRAPHIC PROTECTION"
#   },
#   {
#     "control_id": "SI-7(7)",
#     "control_title": "Integration of Detection and Response",
#     "control_desc": "INTEGRATION OF DETECTION AND RESPONSE"
#   },
#   {
#     "control_id": "SI-7(8)",
#     "control_title": "Auditing Capability for Significant Events",
#     "control_desc": "AUDITING CAPABILITY FOR SIGNIFICANT EVENTS"
#   },
#   {
#     "control_id": "SI-7(9)",
#     "control_title": "Verify Boot Process",
#     "control_desc": "VERIFY BOOT PROCESS"
#   },
#   {
#     "control_id": "SI-7(10)",
#     "control_title": "Protection of Boot Firmware",
#     "control_desc": "PROTECTION OF BOOT FIRMWARE"
#   },
#   {
#     "control_id": "SI-7(11)",
#     "control_title": "Confined Environments with Limited Privileges",
#     "control_desc": "CONFINED ENVIRONMENTS WITH LIMITED PRIVILEGES"
#   },
#   {
#     "control_id": "SI-7(12)",
#     "control_title": "Integrity Verification",
#     "control_desc": "INTEGRITY VERIFICATION"
#   },
#   {
#     "control_id": "SI-7(13)",
#     "control_title": "Code Execution in Protected Environments",
#     "control_desc": "CODE EXECUTION IN PROTECTED ENVIRONMENTS"
#   },
#   {
#     "control_id": "SI-7(14)",
#     "control_title": "Binary or Machine Executable Code",
#     "control_desc": "BINARY OR MACHINE EXECUTABLE CODE"
#   },
#   {
#     "control_id": "SI-7(15)",
#     "control_title": "Code Authentication",
#     "control_desc": "CODE AUTHENTICATION"
#   },
#   {
#     "control_id": "SI-7(16)",
#     "control_title": "Time Limit on Process Execution Without Supervision",
#     "control_desc": "TIME LIMIT ON PROCESS EXECUTION WITHOUT SUPERVISION"
#   },
#   {
#     "control_id": "SI-7(17)",
#     "control_title": "Runtime Application Self-Protection",
#     "control_desc": "RUNTIME APPLICATION SELF-PROTECTION"
#   },
#   {
#     "control_id": "SI-8",
#     "control_title": "Spam Protection",
#     "control_desc": "SPAM PROTECTION"
#   },
#   {
#     "control_id": "SI-8(1)",
#     "control_title": "Central Management",
#     "control_desc": "CENTRAL MANAGEMENT"
#   },
#   {
#     "control_id": "SI-8(2)",
#     "control_title": "Automatic Updates",
#     "control_desc": "AUTOMATIC UPDATES"
#   },
#   {
#     "control_id": "SI-8(3)",
#     "control_title": "Continuous Learning Capability",
#     "control_desc": "CONTINUOUS LEARNING CAPABILITY"
#   },
#   {
#     "control_id": "SI-9",
#     "control_title": "Information Input Restrictions",
#     "control_desc": "INFORMATION INPUT RESTRICTIONS"
#   },
#   {
#     "control_id": "SI-10",
#     "control_title": "Information Input Validation",
#     "control_desc": "INFORMATION INPUT VALIDATION"
#   },
#   {
#     "control_id": "SI-10(1)",
#     "control_title": "Manual Override Capability",
#     "control_desc": "MANUAL OVERRIDE CAPABILITY"
#   },
#   {
#     "control_id": "SI-10(2)",
#     "control_title": "Review and Resolve Errors",
#     "control_desc": "REVIEW AND RESOLVE ERRORS"
#   },
#   {
#     "control_id": "SI-10(3)",
#     "control_title": "Predictable Behavior",
#     "control_desc": "PREDICTABLE BEHAVIOR"
#   },
#   {
#     "control_id": "SI-10(4)",
#     "control_title": "Timing Interactions",
#     "control_desc": "TIMING INTERACTIONS"
#   },
#   {
#     "control_id": "SI-10(5)",
#     "control_title": "Restrict Inputs to Trusted Sources and Approved Formats",
#     "control_desc": "RESTRICT INPUTS TO TRUSTED SOURCES AND APPROVED FORMATS"
#   },
#   {
#     "control_id": "SI-10(6)",
#     "control_title": "Injection Prevention",
#     "control_desc": "INJECTION PREVENTION"
#   },
#   {
#     "control_id": "SI-11",
#     "control_title": "Error Handling",
#     "control_desc": "ERROR HANDLING"
#   },
#   {
#     "control_id": "SI-12",
#     "control_title": "Information Management and Retention",
#     "control_desc": "INFORMATION MANAGEMENT AND RETENTION"
#   },
#   {
#     "control_id": "SI-12(1)",
#     "control_title": "Limit Personally Identifiable Information Elements",
#     "control_desc": "LIMIT PERSONALLY IDENTIFIABLE INFORMATION ELEMENTS"
#   },
#   {
#     "control_id": "SI-13(1)",
#     "control_title": "Transferring Component Responsibilities",
#     "control_desc": "SI-13(1) TRANSFERRING COMPONENT RESPONSIBILITIES"
#   },
#   {
#     "control_id": "SI-13(2)",
#     "control_title": "Time Limit on Process Execution Without Supervision",
#     "control_desc": "SI-13(2) TIME LIMIT ON PROCESS EXECUTION WITHOUT SUPERVISION W: Incorporated into SI-7(16)."
#   },
#   {
#     "control_id": "SI-13(3)",
#     "control_title": "Manual Transfer Between Components",
#     "control_desc": "SI-13(3) MANUAL TRANSFER BETWEEN COMPONENTS"
#   },
#   {
#     "control_id": "SI-13(4)",
#     "control_title": "Standby Component Installation and Notification",
#     "control_desc": "SI-13(4) STANDBY COMPONENT INSTALLATION AND NOTIFICATION"
#   },
#   {
#     "control_id": "SI-13(5)",
#     "control_title": "Failover Capability",
#     "control_desc": "SI-13(5) FAILOVER CAPABILITY"
#   },
#   {
#     "control_id": "SI-14(1)",
#     "control_title": "Refresh from Trusted Sources",
#     "control_desc": "SI-14(1) REFRESH FROM TRUSTED SOURCES"
#   },
#   {
#     "control_id": "SI-14(2)",
#     "control_title": "Non-Persistent Information",
#     "control_desc": "SI-14(2) NON-PERSISTENT INFORMATION"
#   },
#   {
#     "control_id": "SI-14(3)",
#     "control_title": "Non-Persistent Connectivity",
#     "control_desc": "SI-14(3) NON-PERSISTENT CONNECTIVITY"
#   },
#   {
#     "control_id": "SI-15",
#     "control_title": "Information Output Filtering",
#     "control_desc": "SI-15 Information Output Filtering"
#   },
#   {
#     "control_id": "SI-16",
#     "control_title": "Memory Protection",
#     "control_desc": "SI-16 Memory Protection"
#   },
#   {
#     "control_id": "SI-17",
#     "control_title": "Fail-Safe Procedures",
#     "control_desc": "SI-17 Fail-Safe Procedures"
#   },
#   {
#     "control_id": "SI-18",
#     "control_title": "Personally Identifiable Information Quality Operations",
#     "control_desc": "SI-18 Personally Identifiable Information Quality Operations"
#   },
#   {
#     "control_id": "SI-18(1)",
#     "control_title": "Automation Support",
#     "control_desc": "SI-18(1) AUTOMATION SUPPORT"
#   },
#   {
#     "control_id": "SI-18(2)",
#     "control_title": "Data Tags",
#     "control_desc": "SI-18(2) DATA TAGS"
#   },
#   {
#     "control_id": "SI-18(3)",
#     "control_title": "Collection",
#     "control_desc": "SI-18(3) COLLECTION"
#   },
#   {
#     "control_id": "SI-18(4)",
#     "control_title": "Individual Requests",
#     "control_desc": "SI-18(4) INDIVIDUAL REQUESTS"
#   },
#   {
#     "control_id": "SI-18(5)",
#     "control_title": "Notice of Correction or Deletion",
#     "control_desc": "SI-18(5) NOTICE OF CORRECTION OR DELETION"
#   },
#   {
#     "control_id": "SI-19",
#     "control_title": "De-Identification",
#     "control_desc": "SI-19 De-Identification"
#   },
#   {
#     "control_id": "SI-19(1)",
#     "control_title": "Collection",
#     "control_desc": "SI-19(1) COLLECTION"
#   },
#   {
#     "control_id": "SI-19(2)",
#     "control_title": "Archiving",
#     "control_desc": "SI-19(2) ARCHIVING"
#   },
#   {
#     "control_id": "SI-19(3)",
#     "control_title": "Release",
#     "control_desc": "SI-19(3) RELEASE"
#   },
#   {
#     "control_id": "SI-19(4)",
#     "control_title": "Removal, Masking, Encryption, Hashing, or Replacement of Direct Identifiers",
#     "control_desc": "SI-19(4) REMOVAL, MASKING, ENCRYPTION, HASHING, OR REPLACEMENT OF DIRECT IDENTIFIERS"
#   },
#   {
#     "control_id": "SI-19(5)",
#     "control_title": "Statistical Disclosure Control",
#     "control_desc": "SI-19(5) STATISTICAL DISCLOSURE CONTROL"
#   },
#   {
#     "control_id": "SI-19(6)",
#     "control_title": "Differential Privacy",
#     "control_desc": "SI-19(6) DIFFERENTIAL PRIVACY"
#   },
#   {
#     "control_id": "SI-19(7)",
#     "control_title": "Validated Algorithms and Software",
#     "control_desc": "SI-19(7) VALIDATED ALGORITHMS AND SOFTWARE"
#   },
#   {
#     "control_id": "SI-19(8)",
#     "control_title": "Motivated Intruder",
#     "control_desc": "SI-19(8) MOTIVATED INTRUDER"
#   },
#   {
#     "control_id": "SI-20",
#     "control_title": "Tainting",
#     "control_desc": "SI-20 Tainting"
#   },
#   {
#     "control_id": "SI-21",
#     "control_title": "Information Refresh",
#     "control_desc": "SI-21 Information Refresh"
#   },
#   {
#     "control_id": "SI-22",
#     "control_title": "Information Diversity",
#     "control_desc": "SI-22 Information Diversity"
#   },
#   {
#     "control_id": "SI-23",
#     "control_title": "Information Fragmentation",
#     "control_desc": "SI-23 Information Fragmentation"
#   },
#   {
#     "control_id": "SR-1",
#     "control_title": "Policy and Procedures",
#     "control_desc": "Policy and Procedures for supply chain risk management."
#   },
#   {
#     "control_id": "SR-2",
#     "control_title": "Supply Chain Risk Management Plan",
#     "control_desc": "Establishment of a supply chain risk management plan."
#   },
#   {
#     "control_id": "SR-2(1)",
#     "control_title": "Establish SCRM Team",
#     "control_desc": "Formation of a supply chain risk management team."
#   },
#   {
#     "control_id": "SR-3",
#     "control_title": "Supply Chain Controls and Processes",
#     "control_desc": "Implementation of supply chain controls and processes."
#   },
#   {
#     "control_id": "SR-3(1)",
#     "control_title": "Diverse Supply Base",
#     "control_desc": "Ensuring a diverse supply base."
#   },
#   {
#     "control_id": "SR-3(2)",
#     "control_title": "Limitation of Harm",
#     "control_desc": "Limiting potential harm in the supply chain."
#   },
#   {
#     "control_id": "SR-3(3)",
#     "control_title": "Sub-tier Flow Down",
#     "control_desc": "Flow down of supply chain risk management to sub-tiers."
#   },
#   {
#     "control_id": "SR-4",
#     "control_title": "Provenance",
#     "control_desc": "Verification of supply chain provenance."
#   },
#   {
#     "control_id": "SR-4(1)",
#     "control_title": "Identity",
#     "control_desc": "Verification of identity in the supply chain."
#   },
#   {
#     "control_id": "SR-4(2)",
#     "control_title": "Track and Trace",
#     "control_desc": "Tracking and tracing of supply chain items."
#   },
#   {
#     "control_id": "SR-4(3)",
#     "control_title": "Validate as Genuine and Not Altered",
#     "control_desc": "Validation of supply chain items as genuine and not altered."
#   },
#   {
#     "control_id": "SR-4(4)",
#     "control_title": "Supply Chain Integrity \u2014 Pedigree",
#     "control_desc": "Ensuring supply chain integrity through pedigree verification."
#   },
#   {
#     "control_id": "SR-5",
#     "control_title": "Acquisition Strategies, Tools, and Methods",
#     "control_desc": "Use of acquisition strategies, tools, and methods for supply chain management."
#   },
#   {
#     "control_id": "SR-5(1)",
#     "control_title": "Adequate Supply",
#     "control_desc": "Ensuring adequate supply in the supply chain."
#   },
#   {
#     "control_id": "SR-5(2)",
#     "control_title": "Assessments Prior to Selection, Acceptance, Modification, or Update",
#     "control_desc": "Pre-selection assessments for supply chain items."
#   },
#   {
#     "control_id": "SR-6",
#     "control_title": "Supplier Assessments and Reviews",
#     "control_desc": "Conducting supplier assessments and reviews."
#   },
#   {
#     "control_id": "SR-6(1)",
#     "control_title": "Testing and Analysis",
#     "control_desc": "Testing and analysis of suppliers."
#   },
#   {
#     "control_id": "SR-7",
#     "control_title": "Supply Chain Operations Security",
#     "control_desc": "Ensuring security in supply chain operations."
#   },
#   {
#     "control_id": "SR-8",
#     "control_title": "Notification Agreements",
#     "control_desc": "Establishing notification agreements in the supply chain."
#   },
#   {
#     "control_id": "SR-9",
#     "control_title": "Tamper Resistance and Detection",
#     "control_desc": "Ensuring tamper resistance and detection in the supply chain."
#   },
#   {
#     "control_id": "SR-9(1)",
#     "control_title": "Multiple Stages of System Development Life Cycle",
#     "control_desc": "Incorporating multiple stages of system development life cycle for tamper resistance."
#   },
#   {
#     "control_id": "SR-10",
#     "control_title": "Inspection of Systems or Components",
#     "control_desc": "Performing inspections on systems or components in the supply chain."
#   },
#   {
#     "control_id": "SR-11",
#     "control_title": "Component Authenticity",
#     "control_desc": "Ensuring component authenticity in the supply chain."
#   },
#   {
#     "control_id": "SR-11(1)",
#     "control_title": "Anti-counterfeit Training",
#     "control_desc": "Providing anti-counterfeit training for supply chain personnel."
#   },
#   {
#     "control_id": "SR-11(2)",
#     "control_title": "Configuration Control for Component Service and Repair",
#     "control_desc": "Controlling configuration for service and repair of supply chain components."
#   },
#   {
#     "control_id": "SR-11(3)",
#     "control_title": "Anti-counterfeit Scanning",
#     "control_desc": "Scanning for anti-counterfeit measures in the supply chain."
#   },
#   {
#     "control_id": "SR-12",
#     "control_title": "Component Disposal",
#     "control_desc": "Managing the disposal of supply chain components."
#   }
# ]

# %%
with open("output.json", "w") as f:
    json.dump(clean_json_string, f, indent=2)

# %%
import json
with open('output.json',"r") as f:
    all_extracted_data = json.load(f)

# %%
print(f"the extraction loop took {minutes}m {seconds}s to finish.")
# Out:
# the extraction loop took 8m 3s to finish.

# %%
from langchain_huggingface import HuggingFacePipeline, HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_core.prompts import PromptTemplate

from langchain_classic.chains import LLMChain

# %%
from huggingface_hub import login
from dotenv import load_dotenv
import os
load_dotenv()
login(token=os.environ['hf_token'])

# %%
def load_model(model_id="Qwen/Qwen2.5-7B-Instruct"):

    bnb_config = BitsAndBytesConfig(load_in_4bit=True,
                                    bnb_4bit_use_double_quant=True,
                                    bnb_4bit_quant_type="nf4",
                                    bnb_4bit_compute_dtype=torch.float16)
    
    # tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_id)

    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
        
    # 2. Set padding side to 'left' for generation (Important for decoder-only models)
    tokenizer.padding_side = "left"

    # model
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=True
    )
    return tokenizer,model

# %%
def setup_langchain_rag(text_pages):
    # using langchain document extraction because it takes care of metadata
    # which makes sure that the model understands the context of the chunk (which page the chunk is from).
    documents = []
    for i,page_text in enumerate(text_pages):
        doc = Document(page_content=page_text, metadata={"page_number": i + 1, "source": "pdf_upload"})
        documents.append(doc)
    # using a lightweight embedding model
    # which stores the vector embeddings of the pdf file.
    embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vectorstore = Chroma.from_documents(
        documents=documents, 
        embedding=embeddings,
        collection_name="pdf_validation_store"
    )
    tokenizer,model = load_model()
    
    # Creating the Pipeline based on the model loaded already
    text_generation_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=1024,
        temperature=0.1, # Low temp for strict validation
        do_sample=True,                # Switch to True to make penalty work better
        top_p=0.9,                     # Standard sampling
        repetition_penalty=1.15,      
        pad_token_id=tokenizer.eos_token_id
    
    )
    
    llm = HuggingFacePipeline(pipeline=text_generation_pipeline)
    
    return vectorstore, llm

# %%
def validate_extracted_controls(extracted_controls, vectorstore, llm):
    # prompt for the validation llm
    validation_template = """
    You are a Quality Assurance Auditor. Verify if the following control exists in the source text.
    
    SOURCE TEXT (Reference):
    {context}
    
    CLAIMED CONTROL (To Verify):
    ID: {control_id}
    Title: {control_title}
    Description: {control_desc}
    
    TASK:
    Determine if the "Claimed Control" is explicitly supported by the "Source Text".
    Also make sure the control given isnt just a change made in any other control
    
    OUTPUT FORMAT:
    Return only a JSON object with this format:
    {{
        "is_valid": true/false,
        "reason": "Short explanation citing the text",
        "confidence_score": 1-10
    }}
    """
    # put the prompt into proper template for the model pipeline
    prompt = PromptTemplate(
        template=validation_template,
        input_variables=["context", "control_id", "control_title", "control_desc"]
    )
    
    # Creating a chain manually for better control
    retriever = vectorstore.as_retriever(search_kwargs={"k": 1}) # Retrieve top 1 page
    
    validated_results = []
    
    for control in extracted_controls:
        # Retrieval of the relvant chunk using control id and control description for better accuracy
        query = f"{control['control_id']} {control['control_desc']}"
        relevant_docs = retriever.invoke(query)
        
        # taking the content of the most relevant chunk
        context_text = relevant_docs[0].page_content if relevant_docs else "No context found."
        found_page = relevant_docs[0].metadata['page_number'] if relevant_docs else "Unknown"

        # passing the content and control to the model to validate the control extracted.
        chain = prompt | llm
        
        try:
            # Run the validation
            response = chain.invoke({
                "context": context_text,
                "control_id": control['control_id'],
                "control_title": control['control_title'],
                "control_desc": control['control_desc']
            })
            
            # Clean up response to get JSON (Model might chatter)
            response_clean = response.split("{")[-1].split("}")[0]
            response_clean=response.split("```json")[1].split('```')[0].strip()
            response_json = json.loads(response_clean )
            
            # Add validation metadata to the control
            control['validation'] = {
                'status': 'PASS' if response_json.get('is_valid') else 'FAIL',
                'verified_on_page': found_page,
                'reason': response_json.get('reason')
            }
            
        except Exception as e:
            control['validation'] = {'status': 'ERROR', 'reason': str(e)}
            # print(response[:50],"...",response[-50:])
            
        validated_results.append(control)
        print(f" > Checked {control['control_id']}: {control['validation']['status']}")
        

    return validated_results

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# Setup Vector Store using the text_pages you already cleaned
vectorstore, langchain_llm = setup_langchain_rag(text_page)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
# Validate the extracted data
final_validated_data = validate_extracted_controls(all_extracted_data[:10], vectorstore, langchain_llm)
# Out:
# {
#     "is_valid": true,
#     "reason": "The source text describes 'Policy and Procedures' under the 'MA-1 POLICY AND PROCEDURES' section, which aligns with the claimed control ID MP-1 titled 'Policy and Procedures'.",
#     "confidence_score": 10
# }
#  > Checked MP-1: PASS
# {
#     "is_valid": true,
#     "reason": "The source text lists 'Media Access' as control number MP-2.",
#     "confidence_score": 9
# }
#  > Checked MP-2: PASS
# {
#     "is_valid": true,
#     "reason": "The source text lists 'MP-2(1) AUTOMATED RESTRICTED ACCESS' as implemented.",
#     "confidence_score": 9
# }
#  > Checked MP-2(1): PASS
# {
#     "is_valid": false,
#     "reason": "The source text does not contain the specific term 'Cryptographic Protection' nor any explicit reference to the control ID MP-2(2). While it mentions 'cryptographic module', which relates to cryptography, there is no direct mention of the control title or ID.",
#     "confidence_score": 8
# }
#  > Checked MP-2(2): FAIL
# {
#     "is_valid": true,
#     "reason": "The source text explicitly mentions 'MP-3 Media Marking' which matches the claimed control.",
#     "confidence_score": 9
# }
#  > Checked MP-3: PASS
# {
#     "is_valid": true,
#     "reason": "The source text discusses 'Media Storage' under the title 'MP-4', which matches the claimed control ID and description.",
#     "confidence_score": 10
# }
#  > Checked MP-4: PASS
# {
#     "is_valid": false,
#     "reason": "The source text does not contain any explicit reference to 'Cryptographic Protection' as defined by the claimed control.",
#     "confidence_score": 8
# }
#  > Checked MP-4(1): FAIL
# {
#         "is_valid": false,
#         "reason": "The source text does not list 'Automated Restricted Access' as an individual control but instead mentions it under MP-2(1).",
#         "confidence_score": 9
#     }
#  > Checked MP-4(2): FAIL
# {
#     "is_valid": true,
#     "reason": "The source text explicitly describes 'Media Transport' under the title 'MP-5 MEDIA TRANSPORT', matching the claimed control.",
#     "confidence_score": 10
# }
#  > Checked MP-5: PASS
# {
#     "is_valid": false,
#     "reason": "The source text does not contain any information related to 'Protection Outside of Controlled Areas'. The text provided is an excerpt from NIST SP 800-53 Rev. 5 which lists general metadata such as availability and references but does not include details for individual controls.",
#     "confidence_score": 10
# }
#  > Checked MP-5(1): FAIL

# %%
# 3. Save Final Result
with open(f"extracted_controls/output_validated.json", "w", encoding="utf-8") as f:
    json.dump(final_validated_data, f, indent=2, ensure_ascii=False)
